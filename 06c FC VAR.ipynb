# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, SequentialSampler, Subset
from utils import get_lags, get_average, train_window, Window

# %%
class CoreDataset(Dataset):
    
    def __init__(self, df: pd.DataFrame, lags: int, series: str):
        # start from 1948
        core: pd.DataFrame = df[["CPIAUCSL", "UNRATE", "A191RO1Q156NBEA"]].loc["1948-01-01":]
        
        X = get_lags(core, lags)
        self.y = core[lags:][series].values
        self.X = X[lags:].values
        
    def __getitem__(self, index):
        return self.y[index], self.X[index]
    
    def __len__(self):
        return len(self.y)
    
    def plot(self):
        plt.plot(self.core)
        plt.show()

full = pd.read_csv('growth_rate.csv', index_col=0, header=[0], parse_dates=True)
cpidata = CoreDataset(full, lags=3, series="CPIAUCSL")
gdpdata = CoreDataset(full, lags=3, series="A191RO1Q156NBEA")
uedata = CoreDataset(full, lags=3, series="UNRATE")

# %%
def generate_window(dataset: Dataset):
    windows = []
    train_size = 400
    val_size = 100
    test_from = 700
    train_start = 0
    
    # reserve test set first
    testset = Subset(dataset, [i for i in range(test_from + 1, len(dataset))])
    testloader = DataLoader(testset, batch_size=1, shuffle=False, sampler=SequentialSampler(testset))
    
    # generate training windows
    while train_start + train_size + val_size <= test_from:
        train_end = train_start + train_size
        print("Generating training set from: %d to %d" % (train_start, train_end))
        trainset = Subset(dataset, [i for i in range(train_start, train_end)])
        
        val_start = train_end + 1
        val_end = train_end + val_size
        print("Generating validation set from %d to %d" % (val_start, val_end))
        valset = Subset(dataset, [i for i in range(val_start, val_end)])
        
        train_start += 100
        
        trainloader = DataLoader(trainset, batch_size=1, shuffle=False, sampler=SequentialSampler(trainset))
        validationloader = DataLoader(valset, batch_size=1, shuffle=False, sampler=SequentialSampler(valset))
        
        windows.append(Window(trainloader=trainloader, validationloader=validationloader))
    
    print(str(len(windows)) + " windows generated")
    return testloader, windows

cpi_test, cpi_windows = generate_window(cpidata)
gdp_test, gdp_windows = generate_window(gdpdata)
ue_test, ue_windows = generate_window(uedata)

# make sure the following are in the same order
top_windows = cpi_windows, gdp_windows, ue_windows
testloaders = cpi_test, gdp_test, ue_test
# Out:
# Generating training set from: 0 to 400
# Generating validation set from 401 to 500
# Generating training set from: 100 to 500
# Generating validation set from 501 to 600
# Generating training set from: 200 to 600
# Generating validation set from 601 to 700
# 3 windows generated
# Generating training set from: 0 to 400
# Generating validation set from 401 to 500
# Generating training set from: 100 to 500
# Generating validation set from 501 to 600
# Generating training set from: 200 to 600
# Generating validation set from 601 to 700
# 3 windows generated
# Generating training set from: 0 to 400
# Generating validation set from 401 to 500
# Generating training set from: 100 to 500
# Generating validation set from 501 to 600
# Generating training set from: 200 to 600
# Generating validation set from 601 to 700
# 3 windows generated

# %%
class Feedforward(nn.Module):
    
    def __init__(self):
        super(Feedforward, self).__init__()
        self.fc1 = nn.Linear(9, 6)
        self.fc2 = nn.Linear(6, 6)
        self.fc3 = nn.Linear(6, 1)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)  # no activation at output layer
        return x

nets = [Feedforward() for _ in range(3)]

# %%
criteria = [nn.MSELoss() for _ in range(3)]

# https://stackoverflow.com/questions/35540269/keras-giving-same-loss-on-every-epoch
optimizers = [torch.optim.SGD(nets[i].parameters(), lr=0.001) for i in range(3)]

# %%
for j in range(3):
    windows = top_windows[j]
    print("Training new net")
    for i, window in enumerate(windows):
        print("Training in window " + str(i + 1))
        train_window(nets[j], criteria[j], optimizers[j], window)

print("Finished training")
# Out:
# Training new net
# Training in window 1
# [epoch: 1] train loss: 4.733, val loss: 23.447
# [epoch: 6] train loss: 0.386, val loss: 10.475
# [epoch: 11] train loss: 0.329, val loss: 8.794
# [epoch: 16] train loss: 0.289, val loss: 7.466
# [epoch: 21] train loss: 0.269, val loss: 6.331
# [epoch: 26] train loss: 0.257, val loss: 5.545
# [epoch: 31] train loss: 0.249, val loss: 5.028
# [epoch: 36] train loss: 0.245, val loss: 4.620
# [epoch: 41] train loss: 0.242, val loss: 4.542
# [epoch: 46] train loss: 0.240, val loss: 4.415
# [epoch: 51] train loss: 0.237, val loss: 4.393
# [epoch: 56] train loss: 0.236, val loss: 4.176
# [epoch: 61] train loss: 0.232, val loss: 3.975
# [epoch: 66] train loss: 0.231, val loss: 3.862
# [epoch: 71] train loss: 0.229, val loss: 3.799
# [epoch: 76] train loss: 0.228, val loss: 3.794
# [epoch: 81] train loss: 0.226, val loss: 3.749
# [epoch: 86] train loss: 0.225, val loss: 3.530
# [epoch: 91] train loss: 0.223, val loss: 3.457
# [epoch: 96] train loss: 0.221, val loss: 3.224
# [epoch: 101] train loss: 0.219, val loss: 3.155
# [epoch: 106] train loss: 0.219, val loss: 2.949
# [epoch: 111] train loss: 0.218, val loss: 2.984
# [epoch: 116] train loss: 0.217, val loss: 2.913
# [epoch: 121] train loss: 0.217, val loss: 2.841
# [epoch: 126] train loss: 0.217, val loss: 2.798
# [epoch: 131] train loss: 0.216, val loss: 2.766
# [epoch: 136] train loss: 0.217, val loss: 2.644
# [epoch: 141] train loss: 0.216, val loss: 2.734
# [epoch: 146] train loss: 0.216, val loss: 2.456
# [epoch: 151] train loss: 0.216, val loss: 2.411
# [epoch: 156] train loss: 0.214, val loss: 2.364
# [epoch: 161] train loss: 0.212, val loss: 2.126
# [epoch: 166] train loss: 0.209, val loss: 2.273
# [epoch: 171] train loss: 0.209, val loss: 2.236
# [epoch: 176] train loss: 0.208, val loss: 2.189
# [epoch: 181] train loss: 0.208, val loss: 2.139
# [epoch: 186] train loss: 0.208, val loss: 1.839
# [epoch: 191] train loss: 0.207, val loss: 1.884
# [epoch: 196] train loss: 0.207, val loss: 1.894
# [epoch: 201] train loss: 0.206, val loss: 1.855
# [epoch: 206] train loss: 0.206, val loss: 1.809
# [epoch: 211] train loss: 0.207, val loss: 1.729
# [epoch: 216] train loss: 0.207, val loss: 1.735
# [epoch: 221] train loss: 0.208, val loss: 1.550
# [epoch: 226] train loss: 0.206, val loss: 1.633
# [epoch: 231] train loss: 0.205, val loss: 1.662
# [epoch: 236] train loss: 0.208, val loss: 1.567
# [epoch: 241] train loss: 0.208, val loss: 1.551
# [epoch: 246] train loss: 0.208, val loss: 1.520
# [epoch: 251] train loss: 0.207, val loss: 1.460
# [epoch: 256] train loss: 0.207, val loss: 1.397
# [epoch: 261] train loss: 0.206, val loss: 1.372
# [epoch: 266] train loss: 0.210, val loss: 1.404
# [epoch: 271] train loss: 0.209, val loss: 1.460
# [epoch: 276] train loss: 0.209, val loss: 1.467
# [epoch: 281] train loss: 0.209, val loss: 1.472
# [epoch: 286] train loss: 0.210, val loss: 1.376
# [epoch: 291] train loss: 0.207, val loss: 1.485
# [epoch: 296] train loss: 0.209, val loss: 1.387
# [epoch: 301] train loss: 0.210, val loss: 1.356
# [epoch: 306] train loss: 0.208, val loss: 1.418
# [epoch: 311] train loss: 0.209, val loss: 1.406
# [epoch: 316] train loss: 0.210, val loss: 1.462
# [epoch: 321] train loss: 0.208, val loss: 1.423
# [epoch: 326] train loss: 0.207, val loss: 1.409
# [epoch: 331] train loss: 0.210, val loss: 1.392
# [epoch: 336] train loss: 0.208, val loss: 1.338
# [epoch: 341] train loss: 0.207, val loss: 1.373
# [epoch: 346] train loss: 0.208, val loss: 1.406
# [epoch: 351] train loss: 0.208, val loss: 1.430
# [epoch: 356] train loss: 0.205, val loss: 1.691
# [epoch: 361] train loss: 0.208, val loss: 1.319
# [epoch: 366] train loss: 0.206, val loss: 1.583
# [epoch: 371] train loss: 0.206, val loss: 1.566
# [epoch: 376] train loss: 0.204, val loss: 1.287
# [epoch: 381] train loss: 0.207, val loss: 1.513
# [epoch: 386] train loss: 0.206, val loss: 1.729
# [epoch: 391] train loss: 0.205, val loss: 1.616
# [epoch: 396] train loss: 0.205, val loss: 1.216
# [epoch: 401] train loss: 0.206, val loss: 1.777
# [epoch: 406] train loss: 0.205, val loss: 1.540
# [epoch: 411] train loss: 0.206, val loss: 1.449
# [epoch: 416] train loss: 0.204, val loss: 1.543
# [epoch: 421] train loss: 0.205, val loss: 1.487
# [epoch: 426] train loss: 0.204, val loss: 1.448
# [epoch: 431] train loss: 0.202, val loss: 1.743
# [epoch: 436] train loss: 0.202, val loss: 1.660
# [epoch: 441] train loss: 0.202, val loss: 1.819
# [epoch: 446] train loss: 0.202, val loss: 1.882
# [epoch: 451] train loss: 0.201, val loss: 1.484
# [epoch: 456] train loss: 0.202, val loss: 1.811
# [epoch: 461] train loss: 0.201, val loss: 1.223
# [epoch: 466] train loss: 0.200, val loss: 1.260
# [epoch: 471] train loss: 0.201, val loss: 1.730
# [epoch: 476] train loss: 0.202, val loss: 1.842
# [epoch: 481] train loss: 0.199, val loss: 1.625
# [epoch: 486] train loss: 0.199, val loss: 1.696
# [epoch: 491] train loss: 0.199, val loss: 1.650
# [epoch: 496] train loss: 0.200, val loss: 1.635
# [epoch: 501] train loss: 0.199, val loss: 1.676
# Finished window
# Training in window 2
# [epoch: 1] train loss: 0.132, val loss: 0.254
# [epoch: 6] train loss: 0.122, val loss: 0.284
# [epoch: 11] train loss: 0.121, val loss: 0.326
# [epoch: 16] train loss: 0.121, val loss: 0.283
# [epoch: 21] train loss: 0.119, val loss: 0.299
# [epoch: 26] train loss: 0.118, val loss: 0.292
# [epoch: 31] train loss: 0.116, val loss: 0.275
# [epoch: 36] train loss: 0.115, val loss: 0.241
# [epoch: 41] train loss: 0.115, val loss: 0.234
# [epoch: 46] train loss: 0.115, val loss: 0.231
# [epoch: 51] train loss: 0.114, val loss: 0.235
# [epoch: 56] train loss: 0.112, val loss: 0.235
# [epoch: 61] train loss: 0.113, val loss: 0.228
# [epoch: 66] train loss: 0.112, val loss: 0.247
# [epoch: 71] train loss: 0.113, val loss: 0.226
# [epoch: 76] train loss: 0.111, val loss: 0.234
# [epoch: 81] train loss: 0.112, val loss: 0.216
# [epoch: 86] train loss: 0.112, val loss: 0.219
# [epoch: 91] train loss: 0.111, val loss: 0.225
# [epoch: 96] train loss: 0.111, val loss: 0.224
# [epoch: 101] train loss: 0.110, val loss: 0.233
# [epoch: 106] train loss: 0.111, val loss: 0.217
# [epoch: 111] train loss: 0.110, val loss: 0.219
# [epoch: 116] train loss: 0.111, val loss: 0.222
# [epoch: 121] train loss: 0.111, val loss: 0.222
# [epoch: 126] train loss: 0.110, val loss: 0.207
# [epoch: 131] train loss: 0.110, val loss: 0.217
# [epoch: 136] train loss: 0.109, val loss: 0.216
# [epoch: 141] train loss: 0.110, val loss: 0.207
# [epoch: 146] train loss: 0.109, val loss: 0.205
# [epoch: 151] train loss: 0.111, val loss: 0.201
# [epoch: 156] train loss: 0.108, val loss: 0.198
# [epoch: 161] train loss: 0.111, val loss: 0.195
# [epoch: 166] train loss: 0.108, val loss: 0.203
# [epoch: 171] train loss: 0.110, val loss: 0.198
# [epoch: 176] train loss: 0.108, val loss: 0.198
# [epoch: 181] train loss: 0.109, val loss: 0.194
# [epoch: 186] train loss: 0.110, val loss: 0.188
# [epoch: 191] train loss: 0.110, val loss: 0.192
# [epoch: 196] train loss: 0.110, val loss: 0.191
# [epoch: 201] train loss: 0.109, val loss: 0.199
# [epoch: 206] train loss: 0.110, val loss: 0.207
# [epoch: 211] train loss: 0.111, val loss: 0.202
# [epoch: 216] train loss: 0.110, val loss: 0.193
# [epoch: 221] train loss: 0.113, val loss: 0.185
# [epoch: 226] train loss: 0.109, val loss: 0.182
# [epoch: 231] train loss: 0.109, val loss: 0.187
# [epoch: 236] train loss: 0.110, val loss: 0.179
# [epoch: 241] train loss: 0.110, val loss: 0.176
# [epoch: 246] train loss: 0.109, val loss: 0.187
# [epoch: 251] train loss: 0.110, val loss: 0.179
# [epoch: 256] train loss: 0.108, val loss: 0.173
# [epoch: 261] train loss: 0.109, val loss: 0.180
# [epoch: 266] train loss: 0.109, val loss: 0.174
# [epoch: 271] train loss: 0.110, val loss: 0.178
# [epoch: 276] train loss: 0.110, val loss: 0.175
# [epoch: 281] train loss: 0.110, val loss: 0.173
# [epoch: 286] train loss: 0.110, val loss: 0.177
# [epoch: 291] train loss: 0.113, val loss: 0.172
# [epoch: 296] train loss: 0.110, val loss: 0.170
# [epoch: 301] train loss: 0.109, val loss: 0.179
# [epoch: 306] train loss: 0.108, val loss: 0.173
# [epoch: 311] train loss: 0.109, val loss: 0.164
# [epoch: 316] train loss: 0.109, val loss: 0.169
# [epoch: 321] train loss: 0.111, val loss: 0.177
# [epoch: 326] train loss: 0.110, val loss: 0.167
# [epoch: 331] train loss: 0.110, val loss: 0.169
# [epoch: 336] train loss: 0.110, val loss: 0.173
# [epoch: 341] train loss: 0.108, val loss: 0.168
# [epoch: 346] train loss: 0.109, val loss: 0.177
# [epoch: 351] train loss: 0.109, val loss: 0.169
# [epoch: 356] train loss: 0.111, val loss: 0.168
# [epoch: 361] train loss: 0.111, val loss: 0.165
# [epoch: 366] train loss: 0.111, val loss: 0.167
# [epoch: 371] train loss: 0.113, val loss: 0.187
# [epoch: 376] train loss: 0.108, val loss: 0.179
# [epoch: 381] train loss: 0.111, val loss: 0.210
# Finished window
# Training in window 3
# [epoch: 1] train loss: 0.126, val loss: 0.193
# [epoch: 6] train loss: 0.107, val loss: 0.203
# [epoch: 11] train loss: 0.114, val loss: 0.200
# [epoch: 16] train loss: 0.108, val loss: 0.198
# [epoch: 21] train loss: 0.104, val loss: 0.176
# [epoch: 26] train loss: 0.105, val loss: 0.195
# [epoch: 31] train loss: 0.104, val loss: 0.187
# [epoch: 36] train loss: 0.103, val loss: 0.188
# [epoch: 41] train loss: 0.105, val loss: 0.180
# [epoch: 46] train loss: 0.104, val loss: 0.191
# [epoch: 51] train loss: 0.105, val loss: 0.182
# [epoch: 56] train loss: 0.104, val loss: 0.191
# [epoch: 61] train loss: 0.104, val loss: 0.184
# [epoch: 66] train loss: 0.105, val loss: 0.187
# [epoch: 71] train loss: 0.104, val loss: 0.185
# [epoch: 76] train loss: 0.105, val loss: 0.184
# [epoch: 81] train loss: 0.103, val loss: 0.189
# [epoch: 86] train loss: 0.104, val loss: 0.185
# [epoch: 91] train loss: 0.102, val loss: 0.185
# [epoch: 96] train loss: 0.102, val loss: 0.172
# [epoch: 101] train loss: 0.105, val loss: 0.169
# [epoch: 106] train loss: 0.103, val loss: 0.165
# [epoch: 111] train loss: 0.106, val loss: 0.165
# [epoch: 116] train loss: 0.103, val loss: 0.163
# [epoch: 121] train loss: 0.107, val loss: 0.162
# [epoch: 126] train loss: 0.105, val loss: 0.161
# [epoch: 131] train loss: 0.103, val loss: 0.161
# [epoch: 136] train loss: 0.109, val loss: 0.160
# [epoch: 141] train loss: 0.104, val loss: 0.161
# [epoch: 146] train loss: 0.105, val loss: 0.159
# [epoch: 151] train loss: 0.105, val loss: 0.161
# [epoch: 156] train loss: 0.106, val loss: 0.160
# [epoch: 161] train loss: 0.106, val loss: 0.161
# [epoch: 166] train loss: 0.106, val loss: 0.161
# [epoch: 171] train loss: 0.108, val loss: 0.160
# [epoch: 176] train loss: 0.104, val loss: 0.160
# [epoch: 181] train loss: 0.105, val loss: 0.162
# [epoch: 186] train loss: 0.106, val loss: 0.160
# [epoch: 191] train loss: 0.104, val loss: 0.162
# [epoch: 196] train loss: 0.102, val loss: 0.163
# [epoch: 201] train loss: 0.103, val loss: 0.163
# [epoch: 206] train loss: 0.102, val loss: 0.163
# [epoch: 211] train loss: 0.103, val loss: 0.163
# [epoch: 216] train loss: 0.105, val loss: 0.160
# [epoch: 221] train loss: 0.105, val loss: 0.159
# [epoch: 226] train loss: 0.106, val loss: 0.160
# [epoch: 231] train loss: 0.104, val loss: 0.159
# [epoch: 236] train loss: 0.108, val loss: 0.160
# [epoch: 241] train loss: 0.107, val loss: 0.160
# [epoch: 246] train loss: 0.106, val loss: 0.163
# [epoch: 251] train loss: 0.106, val loss: 0.159
# [epoch: 256] train loss: 0.105, val loss: 0.160
# [epoch: 261] train loss: 0.106, val loss: 0.162
# [epoch: 266] train loss: 0.104, val loss: 0.163
# [epoch: 271] train loss: 0.106, val loss: 0.162
# Finished window
# Training new net
# Training in window 1
# [epoch: 1] train loss: 1.645, val loss: 7.793
# [epoch: 6] train loss: 0.252, val loss: 3.935
# [epoch: 11] train loss: 0.214, val loss: 2.541
# [epoch: 16] train loss: 0.202, val loss: 2.207
# [epoch: 21] train loss: 0.191, val loss: 2.239
# [epoch: 26] train loss: 0.182, val loss: 2.147
# [epoch: 31] train loss: 0.177, val loss: 2.213
# [epoch: 36] train loss: 0.173, val loss: 2.317
# [epoch: 41] train loss: 0.171, val loss: 2.366
# Finished window
# Training in window 2
# [epoch: 1] train loss: 0.128, val loss: 0.872
# [epoch: 6] train loss: 0.143, val loss: 0.961
# [epoch: 11] train loss: 0.149, val loss: 0.959
# [epoch: 16] train loss: 0.151, val loss: 1.003
# [epoch: 21] train loss: 0.152, val loss: 1.048
# [epoch: 26] train loss: 0.153, val loss: 1.061
# [epoch: 31] train loss: 0.154, val loss: 1.045
# [epoch: 36] train loss: 0.152, val loss: 0.999
# [epoch: 41] train loss: 0.151, val loss: 0.979
# [epoch: 46] train loss: 0.149, val loss: 0.958
# [epoch: 51] train loss: 0.147, val loss: 0.888
# [epoch: 56] train loss: 0.146, val loss: 0.901
# [epoch: 61] train loss: 0.143, val loss: 0.816
# [epoch: 66] train loss: 0.141, val loss: 0.794
# [epoch: 71] train loss: 0.138, val loss: 0.759
# [epoch: 76] train loss: 0.139, val loss: 0.721
# [epoch: 81] train loss: 0.137, val loss: 0.763
# [epoch: 86] train loss: 0.136, val loss: 0.671
# [epoch: 91] train loss: 0.135, val loss: 0.661
# [epoch: 96] train loss: 0.134, val loss: 0.627
# [epoch: 101] train loss: 0.133, val loss: 0.584
# [epoch: 106] train loss: 0.132, val loss: 0.580
# [epoch: 111] train loss: 0.131, val loss: 0.591
# [epoch: 116] train loss: 0.130, val loss: 0.527
# [epoch: 121] train loss: 0.129, val loss: 0.537
# [epoch: 126] train loss: 0.128, val loss: 0.519
# [epoch: 131] train loss: 0.127, val loss: 0.534
# [epoch: 136] train loss: 0.126, val loss: 0.529
# [epoch: 141] train loss: 0.126, val loss: 0.498
# [epoch: 146] train loss: 0.124, val loss: 0.501
# [epoch: 151] train loss: 0.123, val loss: 0.520
# [epoch: 156] train loss: 0.121, val loss: 0.507
# [epoch: 161] train loss: 0.120, val loss: 0.476
# [epoch: 166] train loss: 0.119, val loss: 0.468
# [epoch: 171] train loss: 0.118, val loss: 0.455
# [epoch: 176] train loss: 0.117, val loss: 0.417
# [epoch: 181] train loss: 0.117, val loss: 0.411
# [epoch: 186] train loss: 0.116, val loss: 0.404
# [epoch: 191] train loss: 0.116, val loss: 0.406
# [epoch: 196] train loss: 0.116, val loss: 0.374
# [epoch: 201] train loss: 0.115, val loss: 0.368
# [epoch: 206] train loss: 0.115, val loss: 0.352
# [epoch: 211] train loss: 0.115, val loss: 0.360
# [epoch: 216] train loss: 0.114, val loss: 0.340
# [epoch: 221] train loss: 0.113, val loss: 0.342
# [epoch: 226] train loss: 0.114, val loss: 0.325
# [epoch: 231] train loss: 0.113, val loss: 0.308
# [epoch: 236] train loss: 0.113, val loss: 0.334
# [epoch: 241] train loss: 0.112, val loss: 0.326
# [epoch: 246] train loss: 0.112, val loss: 0.322
# [epoch: 251] train loss: 0.112, val loss: 0.305
# [epoch: 256] train loss: 0.111, val loss: 0.316
# [epoch: 261] train loss: 0.111, val loss: 0.315
# [epoch: 266] train loss: 0.111, val loss: 0.314
# [epoch: 271] train loss: 0.110, val loss: 0.306
# [epoch: 276] train loss: 0.110, val loss: 0.301
# [epoch: 281] train loss: 0.110, val loss: 0.298
# [epoch: 286] train loss: 0.109, val loss: 0.298
# [epoch: 291] train loss: 0.110, val loss: 0.296
# [epoch: 296] train loss: 0.109, val loss: 0.297
# [epoch: 301] train loss: 0.109, val loss: 0.293
# [epoch: 306] train loss: 0.109, val loss: 0.294
# [epoch: 311] train loss: 0.109, val loss: 0.279
# [epoch: 316] train loss: 0.108, val loss: 0.281
# [epoch: 321] train loss: 0.108, val loss: 0.279
# [epoch: 326] train loss: 0.108, val loss: 0.275
# [epoch: 331] train loss: 0.108, val loss: 0.276
# [epoch: 336] train loss: 0.108, val loss: 0.275
# [epoch: 341] train loss: 0.108, val loss: 0.268
# [epoch: 346] train loss: 0.108, val loss: 0.285
# [epoch: 351] train loss: 0.107, val loss: 0.266
# [epoch: 356] train loss: 0.108, val loss: 0.286
# [epoch: 361] train loss: 0.107, val loss: 0.266
# [epoch: 366] train loss: 0.108, val loss: 0.281
# [epoch: 371] train loss: 0.107, val loss: 0.262
# [epoch: 376] train loss: 0.107, val loss: 0.263
# [epoch: 381] train loss: 0.107, val loss: 0.259
# [epoch: 386] train loss: 0.107, val loss: 0.260
# [epoch: 391] train loss: 0.107, val loss: 0.259
# [epoch: 396] train loss: 0.107, val loss: 0.255
# [epoch: 401] train loss: 0.107, val loss: 0.272
# [epoch: 406] train loss: 0.107, val loss: 0.257
# [epoch: 411] train loss: 0.107, val loss: 0.256
# [epoch: 416] train loss: 0.107, val loss: 0.268
# [epoch: 421] train loss: 0.107, val loss: 0.255
# [epoch: 426] train loss: 0.106, val loss: 0.267
# [epoch: 431] train loss: 0.107, val loss: 0.250
# [epoch: 436] train loss: 0.106, val loss: 0.265
# [epoch: 441] train loss: 0.106, val loss: 0.250
# [epoch: 446] train loss: 0.107, val loss: 0.261
# [epoch: 451] train loss: 0.106, val loss: 0.245
# [epoch: 456] train loss: 0.106, val loss: 0.261
# [epoch: 461] train loss: 0.106, val loss: 0.246
# [epoch: 466] train loss: 0.106, val loss: 0.256
# [epoch: 471] train loss: 0.106, val loss: 0.244
# [epoch: 476] train loss: 0.106, val loss: 0.257
# [epoch: 481] train loss: 0.106, val loss: 0.242
# [epoch: 486] train loss: 0.106, val loss: 0.254
# [epoch: 491] train loss: 0.106, val loss: 0.254
# [epoch: 496] train loss: 0.106, val loss: 0.239
# [epoch: 501] train loss: 0.106, val loss: 0.239
# Finished window
# Training in window 3
# [epoch: 1] train loss: 0.080, val loss: 0.044
# [epoch: 6] train loss: 0.077, val loss: 0.044
# [epoch: 11] train loss: 0.077, val loss: 0.047
# [epoch: 16] train loss: 0.076, val loss: 0.045
# Finished window
# Training new net
# Training in window 1
# [epoch: 1] train loss: 0.939, val loss: 2.963
# [epoch: 6] train loss: 0.073, val loss: 0.296
# [epoch: 11] train loss: 0.062, val loss: 0.141
# [epoch: 16] train loss: 0.060, val loss: 0.128
# [epoch: 21] train loss: 0.058, val loss: 0.116
# [epoch: 26] train loss: 0.057, val loss: 0.109
# [epoch: 31] train loss: 0.056, val loss: 0.109
# [epoch: 36] train loss: 0.055, val loss: 0.106
# [epoch: 41] train loss: 0.055, val loss: 0.105
# [epoch: 46] train loss: 0.055, val loss: 0.104
# [epoch: 51] train loss: 0.054, val loss: 0.101
# [epoch: 56] train loss: 0.054, val loss: 0.098
# [epoch: 61] train loss: 0.054, val loss: 0.099
# [epoch: 66] train loss: 0.053, val loss: 0.099
# [epoch: 71] train loss: 0.053, val loss: 0.100
# [epoch: 76] train loss: 0.053, val loss: 0.100
# [epoch: 81] train loss: 0.052, val loss: 0.101
# [epoch: 86] train loss: 0.052, val loss: 0.101
# [epoch: 91] train loss: 0.052, val loss: 0.100
# [epoch: 96] train loss: 0.052, val loss: 0.103
# [epoch: 101] train loss: 0.052, val loss: 0.103
# [epoch: 106] train loss: 0.052, val loss: 0.103
# Finished window
# Training in window 2
# [epoch: 1] train loss: 0.039, val loss: 0.032
# [epoch: 6] train loss: 0.039, val loss: 0.035
# [epoch: 11] train loss: 0.039, val loss: 0.035
# Finished window
# Training in window 3
# [epoch: 1] train loss: 0.031, val loss: 0.017
# [epoch: 6] train loss: 0.030, val loss: 0.017
# [epoch: 11] train loss: 0.030, val loss: 0.018
# [epoch: 16] train loss: 0.031, val loss: 0.019
# Finished window
# Finished training

# %%
# to reset the weights
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform(m.weight)
    
# net.apply(init_weights)

# %%
def evaluate_on_test(testloader: DataLoader, net: nn.Module, criterion: nn.MSELoss):
    y_pred = []
    y_act = []
    running_test_loss = []
    
    for i, data in enumerate(testloader):
        with torch.no_grad():
            y, X = data
            y, X = y.float(), X.float()
            
            loss = criterion(y, net(X))
            running_test_loss.append(loss.item())
        
            y_pred.append(net(X)[0].item())
            y_act.append(y[0].item())
        
    plt.plot(y_pred)
    plt.plot(y_act)
    
    return get_average(running_test_loss)
    
total_mse = 0
    
for i in range(3):
    average_mse = evaluate_on_test(testloaders[i], nets[i], criteria[i])
    total_mse += average_mse
    print("Average MSE on test set: " + str(average_mse))
    
print("Total MSE: " + str(total_mse))
# Out:
# Average MSE on test set: 0.5473502696962127
# Average MSE on test set: 0.1975172633534055
# Average MSE on test set: 0.10381806798433302
# Total MSE: 0.8486856010339512
