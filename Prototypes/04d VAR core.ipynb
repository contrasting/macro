# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
full = pd.read_csv('normalised_growth.csv', index_col=0, header=[0] ,parse_dates=True)
full.head()
# Out:
#             CPIAUCSL  FEDFUNDS  HOUST  INDPRO  INTDSRUSM193N  ISRATIO  M2SL  \
# 1914-01-01       NaN       NaN    NaN     NaN            NaN      NaN   NaN
# 1914-02-01       NaN       NaN    NaN     NaN            NaN      NaN   NaN
# 1914-03-01       NaN       NaN    NaN     NaN            NaN      NaN   NaN
# 1914-04-01       NaN       NaN    NaN     NaN            NaN      NaN   NaN
# 1914-05-01       NaN       NaN    NaN     NaN            NaN      NaN   NaN
#
#             MTSDS133FMS  PAYEMS  PCE ...   CIVPART  GS20  GS3  \
# 1914-01-01          NaN     NaN  NaN ...       NaN   NaN  NaN
# 1914-02-01          NaN     NaN  NaN ...       NaN   NaN  NaN
# 1914-03-01          NaN     NaN  NaN ...       NaN   NaN  NaN
# 1914-04-01          NaN     NaN  NaN ...       NaN   NaN  NaN
# 1914-05-01          NaN     NaN  NaN ...       NaN   NaN  NaN
#
#             IRLTLT01USM156N  M1SL  MCOILWTICO    PPIACO  TCU  TOTALSA  PMI
# 1914-01-01              NaN   NaN         NaN -0.635906  NaN      NaN  NaN
# 1914-02-01              NaN   NaN         NaN -0.543396  NaN      NaN  NaN
# 1914-03-01              NaN   NaN         NaN -0.638258  NaN      NaN  NaN
# 1914-04-01              NaN   NaN         NaN -0.638258  NaN      NaN  NaN
# 1914-05-01              NaN   NaN         NaN -0.640650  NaN      NaN  NaN
#
# [5 rows x 32 columns]

# %%
sliced = full.loc["1948-01-01":"2019-01-01"]
sliced.shape
# Out:
# (853, 32)

# %%
core_series = ["CPIAUCSL", "A191RO1Q156NBEA", "UNRATE"]

core = sliced[core_series]

train = core.loc["1948-01-01":"2006-4-01"]
test = core.loc["2006-05-01":]

print(train.shape)
# Out:
# (700, 3)

# %%
# http://www.statsmodels.org/dev/vector_ar.html
from statsmodels.tsa.vector_ar.var_model import VAR

# %%
model = VAR(train, freq='MS')
model.select_order(15).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results = model.fit(maxlags=15, ic='aic')
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 15, Aug, 2019
# Time:                     16:20:34
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -12.6334
# Nobs:                     686.000    HQIC:                  -13.1557
# Log likelihood:           1834.32    FPE:                1.39181e-06
# AIC:                     -13.4854    Det(Omega_mle):     1.15976e-06
# --------------------------------------------------------------------
# Results for equation CPIAUCSL
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.002217         0.004351            0.510           0.610
# L1.CPIAUCSL                 1.314466         0.039264           33.478           0.000
# L1.A191RO1Q156NBEA         -0.084254         0.040759           -2.067           0.039
# L1.UNRATE                   0.036451         0.038027            0.959           0.338
# L2.CPIAUCSL                -0.223594         0.060226           -3.713           0.000
# L2.A191RO1Q156NBEA          0.137069         0.080008            1.713           0.087
# L2.UNRATE                  -0.036685         0.048354           -0.759           0.448
# L3.CPIAUCSL                -0.122920         0.055637           -2.209           0.027
# L3.A191RO1Q156NBEA          0.031452         0.085408            0.368           0.713
# L3.UNRATE                  -0.133979         0.049015           -2.733           0.006
# L4.CPIAUCSL                 0.046281         0.056011            0.826           0.409
# L4.A191RO1Q156NBEA         -0.161352         0.085906           -1.878           0.060
# L4.UNRATE                   0.065183         0.049187            1.325           0.185
# L5.CPIAUCSL                 0.048760         0.056254            0.867           0.386
# L5.A191RO1Q156NBEA          0.080375         0.088367            0.910           0.363
# L5.UNRATE                   0.072995         0.049150            1.485           0.138
# L6.CPIAUCSL                -0.054294         0.055474           -0.979           0.328
# L6.A191RO1Q156NBEA          0.060649         0.088918            0.682           0.495
# L6.UNRATE                  -0.051265         0.049166           -1.043           0.297
# L7.CPIAUCSL                 0.068877         0.054547            1.263           0.207
# L7.A191RO1Q156NBEA         -0.068064         0.088753           -0.767           0.443
# L7.UNRATE                   0.051461         0.049131            1.047           0.295
# L8.CPIAUCSL                -0.093592         0.054785           -1.708           0.088
# L8.A191RO1Q156NBEA         -0.015489         0.088520           -0.175           0.861
# L8.UNRATE                  -0.059163         0.049025           -1.207           0.228
# L9.CPIAUCSL                 0.071103         0.054847            1.296           0.195
# L9.A191RO1Q156NBEA         -0.060026         0.088358           -0.679           0.497
# L9.UNRATE                   0.045915         0.048971            0.938           0.348
# L10.CPIAUCSL                0.038149         0.054604            0.699           0.485
# L10.A191RO1Q156NBEA         0.072228         0.087369            0.827           0.408
# L10.UNRATE                  0.019926         0.048748            0.409           0.683
# L11.CPIAUCSL               -0.021538         0.054604           -0.394           0.693
# L11.A191RO1Q156NBEA         0.057266         0.084754            0.676           0.499
# L11.UNRATE                 -0.037887         0.048888           -0.775           0.438
# L12.CPIAUCSL               -0.550279         0.052129          -10.556           0.000
# L12.A191RO1Q156NBEA        -0.073961         0.084019           -0.880           0.379
# L12.UNRATE                  0.051279         0.048939            1.048           0.295
# L13.CPIAUCSL                0.557495         0.054805           10.172           0.000
# L13.A191RO1Q156NBEA         0.029702         0.079066            0.376           0.707
# L13.UNRATE                 -0.082288         0.048528           -1.696           0.090
# L14.CPIAUCSL               -0.086363         0.035923           -2.404           0.016
# L14.A191RO1Q156NBEA        -0.011329         0.039765           -0.285           0.776
# L14.UNRATE                  0.052450         0.037832            1.386           0.166
# ======================================================================================
#
# Results for equation A191RO1Q156NBEA
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.004033         0.004015            1.004           0.315
# L1.CPIAUCSL                 0.001630         0.036231            0.045           0.964
# L1.A191RO1Q156NBEA          1.787591         0.037611           47.528           0.000
# L1.UNRATE                   0.048867         0.035090            1.393           0.164
# L2.CPIAUCSL                -0.011423         0.055575           -0.206           0.837
# L2.A191RO1Q156NBEA         -0.812751         0.073829          -11.009           0.000
# L2.UNRATE                  -0.085473         0.044620           -1.916           0.055
# L3.CPIAUCSL                 0.038066         0.051340            0.741           0.458
# L3.A191RO1Q156NBEA         -0.256293         0.078812           -3.252           0.001
# L3.UNRATE                   0.046300         0.045229            1.024           0.306
# L4.CPIAUCSL                -0.091267         0.051685           -1.766           0.077
# L4.A191RO1Q156NBEA          0.490602         0.079272            6.189           0.000
# L4.UNRATE                   0.067451         0.045388            1.486           0.137
# L5.CPIAUCSL                 0.088036         0.051909            1.696           0.090
# L5.A191RO1Q156NBEA         -0.217581         0.081542           -2.668           0.008
# L5.UNRATE                  -0.067515         0.045355           -1.489           0.137
# L6.CPIAUCSL                -0.011084         0.051190           -0.217           0.829
# L6.A191RO1Q156NBEA         -0.105399         0.082051           -1.285           0.199
# L6.UNRATE                   0.061964         0.045369            1.366           0.172
# L7.CPIAUCSL                -0.039639         0.050334           -0.788           0.431
# L7.A191RO1Q156NBEA          0.214916         0.081899            2.624           0.009
# L7.UNRATE                  -0.059759         0.045337           -1.318           0.187
# L8.CPIAUCSL                 0.016679         0.050554            0.330           0.741
# L8.A191RO1Q156NBEA         -0.112160         0.081683           -1.373           0.170
# L8.UNRATE                   0.058264         0.045239            1.288           0.198
# L9.CPIAUCSL                 0.022132         0.050611            0.437           0.662
# L9.A191RO1Q156NBEA         -0.042217         0.081534           -0.518           0.605
# L9.UNRATE                  -0.013338         0.045189           -0.295           0.768
# L10.CPIAUCSL               -0.071328         0.050387           -1.416           0.157
# L10.A191RO1Q156NBEA         0.119619         0.080622            1.484           0.138
# L10.UNRATE                  0.094449         0.044983            2.100           0.036
# L11.CPIAUCSL                0.071174         0.050387            1.413           0.158
# L11.A191RO1Q156NBEA        -0.078466         0.078208           -1.003           0.316
# L11.UNRATE                  0.001482         0.045112            0.033           0.974
# L12.CPIAUCSL               -0.033312         0.048103           -0.693           0.489
# L12.A191RO1Q156NBEA        -0.398780         0.077530           -5.144           0.000
# L12.UNRATE                 -0.073005         0.045159           -1.617           0.106
# L13.CPIAUCSL               -0.010874         0.050573           -0.215           0.830
# L13.A191RO1Q156NBEA         0.704431         0.072960            9.655           0.000
# L13.UNRATE                 -0.130193         0.044780           -2.907           0.004
# L14.CPIAUCSL                0.014190         0.033148            0.428           0.669
# L14.A191RO1Q156NBEA        -0.300142         0.036694           -8.180           0.000
# L14.UNRATE                  0.069439         0.034910            1.989           0.047
# ======================================================================================
#
# Results for equation UNRATE
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.008200         0.004517            1.815           0.069
# L1.CPIAUCSL                -0.026412         0.040769           -0.648           0.517
# L1.A191RO1Q156NBEA         -0.252093         0.042322           -5.957           0.000
# L1.UNRATE                   0.774145         0.039485           19.606           0.000
# L2.CPIAUCSL                 0.049872         0.062535            0.798           0.425
# L2.A191RO1Q156NBEA          0.202001         0.083076            2.432           0.015
# L2.UNRATE                   0.225563         0.050208            4.493           0.000
# L3.CPIAUCSL                -0.094757         0.057771           -1.640           0.101
# L3.A191RO1Q156NBEA         -0.002319         0.088683           -0.026           0.979
# L3.UNRATE                  -0.018320         0.050894           -0.360           0.719
# L4.CPIAUCSL                 0.158191         0.058158            2.720           0.007
# L4.A191RO1Q156NBEA         -0.124035         0.089200           -1.391           0.164
# L4.UNRATE                  -0.010167         0.051073           -0.199           0.842
# L5.CPIAUCSL                -0.121238         0.058411           -2.076           0.038
# L5.A191RO1Q156NBEA          0.196601         0.091755            2.143           0.032
# L5.UNRATE                   0.048481         0.051035            0.950           0.342
# L6.CPIAUCSL                 0.002941         0.057602            0.051           0.959
# L6.A191RO1Q156NBEA         -0.186893         0.092328           -2.024           0.043
# L6.UNRATE                  -0.097701         0.051051           -1.914           0.056
# L7.CPIAUCSL                 0.049114         0.056639            0.867           0.386
# L7.A191RO1Q156NBEA          0.153917         0.092157            1.670           0.095
# L7.UNRATE                   0.024936         0.051015            0.489           0.625
# L8.CPIAUCSL                -0.039249         0.056886           -0.690           0.490
# L8.A191RO1Q156NBEA          0.011221         0.091914            0.122           0.903
# L8.UNRATE                   0.032242         0.050905            0.633           0.526
# L9.CPIAUCSL                -0.008380         0.056950           -0.147           0.883
# L9.A191RO1Q156NBEA         -0.066102         0.091746           -0.720           0.471
# L9.UNRATE                  -0.015015         0.050849           -0.295           0.768
# L10.CPIAUCSL                0.033425         0.056698            0.590           0.556
# L10.A191RO1Q156NBEA         0.001970         0.090719            0.022           0.983
# L10.UNRATE                 -0.087723         0.050617           -1.733           0.083
# L11.CPIAUCSL                0.002330         0.056698            0.041           0.967
# L11.A191RO1Q156NBEA         0.000325         0.088004            0.004           0.997
# L11.UNRATE                  0.100929         0.050763            1.988           0.047
# L12.CPIAUCSL                0.046318         0.054128            0.856           0.392
# L12.A191RO1Q156NBEA         0.080549         0.087240            0.923           0.356
# L12.UNRATE                 -0.082223         0.050815           -1.618           0.106
# L13.CPIAUCSL               -0.084573         0.056907           -1.486           0.137
# L13.A191RO1Q156NBEA        -0.222964         0.082098           -2.716           0.007
# L13.UNRATE                  0.057363         0.050389            1.138           0.255
# L14.CPIAUCSL                0.042053         0.037300            1.127           0.260
# L14.A191RO1Q156NBEA         0.128508         0.041290            3.112           0.002
# L14.UNRATE                  0.022290         0.039283            0.567           0.570
# ======================================================================================
#
# Correlation matrix of residuals
#                    CPIAUCSL  A191RO1Q156NBEA    UNRATE
# CPIAUCSL           1.000000        -0.008199 -0.041087
# A191RO1Q156NBEA   -0.008199         1.000000 -0.102297
# UNRATE            -0.041087        -0.102297  1.000000

# %%
from utils import plot_var_forc

# %%
def plot_forecast_custom(results, steps, previous = 20, alpha=0.05, plot_stderr=True):
    mid, lower, upper = results.forecast_interval(results.y, steps=12, alpha=0.05)
    fig = plot_var_forc(results.y[-previous:], mid, lower, upper, names=results.names, plot_stderr=plot_stderr)
    return fig

# %%
plot_forecast_custom(results, steps = 12)

# %%
lag_order = results.k_ar
forecasts = np.empty((len(test) - lag_order, 3))

for i in range(len(test) - lag_order):
    forecast = results.forecast(test.values[i:lag_order + i], steps=1)
    forecasts[i] = forecast

# %%
plt.plot(test.values[lag_order:])
plt.plot(forecasts)
# Out:
# [<matplotlib.lines.Line2D at 0x1a27349860>,
#  <matplotlib.lines.Line2D at 0x1a273499e8>,
#  <matplotlib.lines.Line2D at 0x1a27349b38>]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(forecasts, test[lag_order:])
print("Average MSE on test set: " + str(mse))
# Out:
# Average MSE on test set: 0.01172952373250502
