# %%
# to import from parent directory
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, SequentialSampler, Subset
from utils import get_lags, get_average, TrainHelper, Window, CoreDataset, evaluate_on_test, init_weights, save_obj, load_obj

# %%
full = pd.read_csv('../normalised_growth.csv', index_col=0, header=[0], parse_dates=True)

# %%
class FeedforwardSixHidden(nn.Module):
    
    def __init__(self, input_size, hidden_size):
        super(FeedforwardSixHidden, self).__init__()
        self.fc1 = nn.Linear(input_size, input_size)
        self.fc2 = nn.Linear(input_size, input_size)
        self.fc3 = nn.Linear(input_size, input_size)
        self.fc4 = nn.Linear(input_size, hidden_size)
        self.fc5 = nn.Linear(hidden_size, hidden_size)
        self.fc6 = nn.Linear(hidden_size, hidden_size)
        self.fc7 = nn.Linear(hidden_size, 3)
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        
    def forward(self, x):
        x_temp = x
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = x + x_temp
        
        x = F.relu(self.fc4(x))
        x_temp = x
        x = F.relu(self.fc5(x))
        x = F.relu(self.fc6(x))
        x = x + x_temp
        
        x = self.fc7(x)
        return x

# %%
trainer = TrainHelper(percent = 0.99, manual = 5000, print_every=1000)

PATH = "./Core Deep/"

def train_times(times, trainer, net, criterion, optimizer, window):
    
    losses = []

    # train ten times, find best loss
    for i in range(times):
        net.apply(init_weights)
        print("Training %d time" % i)
        loss = trainer.train_window(net, criterion, optimizer, window)
        torch.save(net.state_dict(), PATH + "lag" + str(net.input_size//3) + "hidden" + str(net.hidden_size) + "_" + str(i) + ".pt")
        losses.append(loss)
        
    return losses

# %%
length = len(full.loc["1948-01-01":])
val_start = round(length * 0.8)
test_start = round(length * 0.9)

# %%
losses = {}

# %%
hiddens = [6]

for lags in range(1, 15):
    coredata = CoreDataset(full, lags=lags, series=["CPIAUCSL", "A191RO1Q156NBEA", "UNRATE"])

    # subtract by lags to ensure same training sets
    trainset = Subset(coredata, [i for i in range(val_start - 1 - lags)])
    valset = Subset(coredata, [i for i in range(val_start - lags, test_start - 1 - lags)])

    trainloader = DataLoader(trainset, batch_size=1, shuffle=False, sampler=SequentialSampler(trainset))
    validationloader = DataLoader(valset, batch_size=1, shuffle=False, sampler=SequentialSampler(valset))

    window = Window(trainloader, validationloader)
    
    for hidden_size in hiddens:
        print("Training new net, %d lags %d hidden" % (lags, hidden_size))

        net = FeedforwardSixHidden(lags * 3, hidden_size=hidden_size)
        criterion = nn.MSELoss()
        optimizer = optim.SGD(net.parameters(), lr=0.001)
        loss = train_times(10, trainer, net, criterion, optimizer, window)
        print(loss)
        losses[str(lags) + "-" + str(hidden_size)] = loss
# Out:
# Training new net, 1 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.858, val loss: 0.411
# Finished window, trained for 68 epochs, loss: 0.039
# Training 1 time
# [epoch: 1] train loss: 1.158, val loss: 0.303
# Finished window, trained for 45 epochs, loss: 0.036
# Training 2 time
# [epoch: 1] train loss: 0.795, val loss: 0.804
# Finished window, trained for 41 epochs, loss: 0.037
# Training 3 time
# [epoch: 1] train loss: 1.217, val loss: 1.381
# Finished window, trained for 85 epochs, loss: 0.049
# Training 4 time
# [epoch: 1] train loss: 1.782, val loss: 1.146
# Finished window, trained for 51 epochs, loss: 0.043
# Training 5 time
# [epoch: 1] train loss: 1.591, val loss: 0.763
# Finished window, trained for 56 epochs, loss: 0.037
# Training 6 time
# [epoch: 1] train loss: 1.022, val loss: 1.138
# Finished window, trained for 45 epochs, loss: 0.061
# Training 7 time
# [epoch: 1] train loss: 0.909, val loss: 0.874
# Finished window, trained for 70 epochs, loss: 0.055
# Training 8 time
# [epoch: 1] train loss: 1.807, val loss: 0.934
# Finished window, trained for 50 epochs, loss: 0.040
# Training 9 time
# [epoch: 1] train loss: 1.205, val loss: 0.816
# Finished window, trained for 86 epochs, loss: 0.078
# [0.03944893690301493, 0.03557389239602558, 0.03734127410930609, 0.04909505712361458, 0.04301376424595147, 0.03654646035580549, 0.061262998093540466, 0.05518275189496504, 0.039775753388062635, 0.07819111592926122]
# Training new net, 2 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.486, val loss: 0.506
# Finished window, trained for 80 epochs, loss: 0.046
# Training 1 time
# [epoch: 1] train loss: 1.200, val loss: 1.021
# Finished window, trained for 44 epochs, loss: 0.130
# Training 2 time
# [epoch: 1] train loss: 1.268, val loss: 1.208
# Finished window, trained for 114 epochs, loss: 0.109
# Training 3 time
# [epoch: 1] train loss: 0.989, val loss: 0.421
# Finished window, trained for 46 epochs, loss: 0.127
# Training 4 time
# [epoch: 1] train loss: 1.305, val loss: 0.480
# Finished window, trained for 42 epochs, loss: 0.126
# Training 5 time
# [epoch: 1] train loss: 0.780, val loss: 0.857
# Finished window, trained for 24 epochs, loss: 0.064
# Training 6 time
# [epoch: 1] train loss: 1.141, val loss: 1.102
# Finished window, trained for 62 epochs, loss: 0.114
# Training 7 time
# [epoch: 1] train loss: 0.952, val loss: 1.054
# Finished window, trained for 84 epochs, loss: 0.039
# Training 8 time
# [epoch: 1] train loss: 0.940, val loss: 0.682
# Finished window, trained for 52 epochs, loss: 0.058
# Training 9 time
# [epoch: 1] train loss: 0.764, val loss: 1.052
# Finished window, trained for 59 epochs, loss: 0.192
# [0.04568689532313205, 0.1299079638143417, 0.10924352899047673, 0.1269882504869362, 0.12567473806762686, 0.0642443534654483, 0.11423508564384617, 0.03875042683768482, 0.05792948372716852, 0.1922131464852582]
# Training new net, 3 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 1.305, val loss: 1.075
# Finished window, trained for 39 epochs, loss: 0.162
# Training 1 time
# [epoch: 1] train loss: 1.298, val loss: 0.995
# Finished window, trained for 45 epochs, loss: 0.091
# Training 2 time
# [epoch: 1] train loss: 0.943, val loss: 0.741
# Finished window, trained for 83 epochs, loss: 0.063
# Training 3 time
# [epoch: 1] train loss: 1.541, val loss: 0.514
# Finished window, trained for 49 epochs, loss: 0.045
# Training 4 time
# [epoch: 1] train loss: 0.872, val loss: 0.850
# Finished window, trained for 73 epochs, loss: 0.035
# Training 5 time
# [epoch: 1] train loss: 0.812, val loss: 0.691
# Finished window, trained for 77 epochs, loss: 0.078
# Training 6 time
# [epoch: 1] train loss: 0.618, val loss: 0.757
# Finished window, trained for 61 epochs, loss: 0.101
# Training 7 time
# [epoch: 1] train loss: 1.348, val loss: 1.035
# Finished window, trained for 29 epochs, loss: 0.279
# Training 8 time
# [epoch: 1] train loss: 1.029, val loss: 1.128
# Finished window, trained for 52 epochs, loss: 0.080
# Training 9 time
# [epoch: 1] train loss: 0.604, val loss: 0.415
# Finished window, trained for 45 epochs, loss: 0.082
# [0.1620337693078909, 0.09108870682197019, 0.0630562753099309, 0.04517599100215069, 0.03473095898208318, 0.07754121355754642, 0.10129186948590146, 0.27907091451862454, 0.07970571181174141, 0.08163731189061746]
# Training new net, 4 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 1.093, val loss: 1.023
# Finished window, trained for 26 epochs, loss: 0.130
# Training 1 time
# [epoch: 1] train loss: 1.236, val loss: 1.313
# Finished window, trained for 25 epochs, loss: 0.110
# Training 2 time
# [epoch: 1] train loss: 0.704, val loss: 0.436
# Finished window, trained for 51 epochs, loss: 0.094
# Training 3 time
# [epoch: 1] train loss: 0.466, val loss: 0.525
# Finished window, trained for 66 epochs, loss: 0.049
# Training 4 time
# [epoch: 1] train loss: 0.357, val loss: 0.311
# Finished window, trained for 47 epochs, loss: 0.086
# Training 5 time
# [epoch: 1] train loss: 1.427, val loss: 0.761
# Finished window, trained for 49 epochs, loss: 0.126
# Training 6 time
# [epoch: 1] train loss: 1.305, val loss: 1.369
# Finished window, trained for 47 epochs, loss: 0.119
# Training 7 time
# [epoch: 1] train loss: 0.720, val loss: 0.876
# Finished window, trained for 56 epochs, loss: 0.121
# Training 8 time
# [epoch: 1] train loss: 0.663, val loss: 0.522
# Finished window, trained for 45 epochs, loss: 0.111
# Training 9 time
# [epoch: 1] train loss: 0.599, val loss: 0.562
# Finished window, trained for 67 epochs, loss: 0.105
# [0.12971303157152278, 0.10959449581420688, 0.0942745026753412, 0.04875339969608011, 0.08574833809466596, 0.1258298044341762, 0.11855608173520488, 0.12120962427571237, 0.11144893613128067, 0.10472226290719348]
# Training new net, 5 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.541, val loss: 0.781
# Finished window, trained for 66 epochs, loss: 0.098
# Training 1 time
# [epoch: 1] train loss: 0.831, val loss: 1.047
# Finished window, trained for 70 epochs, loss: 0.118
# Training 2 time
# [epoch: 1] train loss: 0.749, val loss: 0.906
# Finished window, trained for 50 epochs, loss: 0.178
# Training 3 time
# [epoch: 1] train loss: 0.611, val loss: 0.479
# Finished window, trained for 55 epochs, loss: 0.087
# Training 4 time
# [epoch: 1] train loss: 0.786, val loss: 1.059
# Finished window, trained for 45 epochs, loss: 0.230
# Training 5 time
# [epoch: 1] train loss: 1.132, val loss: 0.756
# Finished window, trained for 63 epochs, loss: 0.156
# Training 6 time
# [epoch: 1] train loss: 0.974, val loss: 0.921
# Finished window, trained for 36 epochs, loss: 0.185
# Training 7 time
# [epoch: 1] train loss: 1.164, val loss: 1.100
# Finished window, trained for 60 epochs, loss: 0.153
# Training 8 time
# [epoch: 1] train loss: 0.448, val loss: 0.580
# Finished window, trained for 64 epochs, loss: 0.096
# Training 9 time
# [epoch: 1] train loss: 0.898, val loss: 0.381
# Finished window, trained for 51 epochs, loss: 0.072
# [0.09794781130496595, 0.1175983452808806, 0.17775196572634455, 0.0865654593386103, 0.2296095004825688, 0.155627535454308, 0.18534825432351698, 0.15344669044419537, 0.09569645189502113, 0.07234397957320599]
# Training new net, 6 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.712, val loss: 0.509
# Finished window, trained for 42 epochs, loss: 0.074
# Training 1 time
# [epoch: 1] train loss: 0.729, val loss: 1.020
# Finished window, trained for 89 epochs, loss: 0.060
# Training 2 time
# [epoch: 1] train loss: 1.050, val loss: 0.899
# Finished window, trained for 67 epochs, loss: 0.191
# Training 3 time
# [epoch: 1] train loss: 0.448, val loss: 0.942
# Finished window, trained for 50 epochs, loss: 0.323
# Training 4 time
# [epoch: 1] train loss: 0.853, val loss: 0.705
# Finished window, trained for 74 epochs, loss: 0.158
# Training 5 time
# [epoch: 1] train loss: 1.214, val loss: 0.415
# Finished window, trained for 49 epochs, loss: 0.086
# Training 6 time
# [epoch: 1] train loss: 0.633, val loss: 0.836
# Finished window, trained for 52 epochs, loss: 0.105
# Training 7 time
# [epoch: 1] train loss: 0.774, val loss: 0.889
# Finished window, trained for 76 epochs, loss: 0.061
# Training 8 time
# [epoch: 1] train loss: 0.524, val loss: 0.825
# Finished window, trained for 58 epochs, loss: 0.155
# Training 9 time
# [epoch: 1] train loss: 0.960, val loss: 1.108
# Finished window, trained for 85 epochs, loss: 0.179
# [0.07403265791890946, 0.06006026602727954, 0.19067090323318125, 0.3225548757176262, 0.15799236017639987, 0.08647277458678182, 0.10463381656651001, 0.06131381001551727, 0.1546092056997997, 0.17895949430371105]
# Training new net, 7 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.533, val loss: 0.450
# Finished window, trained for 30 epochs, loss: 0.140
# Training 1 time
# [epoch: 1] train loss: 0.874, val loss: 0.933
# Finished window, trained for 46 epochs, loss: 0.077
# Training 2 time
# [epoch: 1] train loss: 0.572, val loss: 0.244
# Finished window, trained for 59 epochs, loss: 0.073
# Training 3 time
# [epoch: 1] train loss: 0.848, val loss: 0.606
# Finished window, trained for 74 epochs, loss: 0.043
# Training 4 time
# [epoch: 1] train loss: 1.116, val loss: 0.997
# Finished window, trained for 60 epochs, loss: 0.076
# Training 5 time
# [epoch: 1] train loss: 1.160, val loss: 0.669
# Finished window, trained for 44 epochs, loss: 0.096
# Training 6 time
# [epoch: 1] train loss: 0.613, val loss: 0.416
# Finished window, trained for 38 epochs, loss: 0.099
# Training 7 time
# [epoch: 1] train loss: 1.491, val loss: 1.257
# Finished window, trained for 79 epochs, loss: 0.068
# Training 8 time
# [epoch: 1] train loss: 0.822, val loss: 0.709
# Finished window, trained for 57 epochs, loss: 0.169
# Training 9 time
# [epoch: 1] train loss: 0.890, val loss: 0.772
# Finished window, trained for 44 epochs, loss: 0.087
# [0.13987868171682874, 0.07742557562134393, 0.07280684131375678, 0.04287072229241912, 0.07551334740333807, 0.09576812985104362, 0.09896762282450629, 0.06837291497510045, 0.16912203966594283, 0.08675168048768468]
# Training new net, 8 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.751, val loss: 1.195
# Finished window, trained for 49 epochs, loss: 0.142
# Training 1 time
# [epoch: 1] train loss: 0.982, val loss: 1.522
# Finished window, trained for 75 epochs, loss: 0.165
# Training 2 time
# [epoch: 1] train loss: 0.976, val loss: 0.454
# Finished window, trained for 51 epochs, loss: 0.096
# Training 3 time
# [epoch: 1] train loss: 1.231, val loss: 0.580
# Finished window, trained for 46 epochs, loss: 0.082
# Training 4 time
# [epoch: 1] train loss: 0.734, val loss: 0.426
# Finished window, trained for 46 epochs, loss: 0.144
# Training 5 time
# [epoch: 1] train loss: 0.947, val loss: 0.427
# Finished window, trained for 65 epochs, loss: 0.073
# Training 6 time
# [epoch: 1] train loss: 0.369, val loss: 0.425
# Finished window, trained for 52 epochs, loss: 0.074
# Training 7 time
# [epoch: 1] train loss: 0.768, val loss: 0.542
# Finished window, trained for 37 epochs, loss: 0.074
# Training 8 time
# [epoch: 1] train loss: 0.520, val loss: 0.326
# Finished window, trained for 42 epochs, loss: 0.072
# Training 9 time
# [epoch: 1] train loss: 0.591, val loss: 0.241
# Finished window, trained for 37 epochs, loss: 0.090
# [0.14221362399014956, 0.1649892649211574, 0.09571625949887962, 0.08210531269980814, 0.14401733622676235, 0.07347868845533287, 0.07399717632672001, 0.07379704587499374, 0.0720812329297141, 0.08995636097890525]
# Training new net, 9 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.614, val loss: 0.440
# Finished window, trained for 68 epochs, loss: 0.056
# Training 1 time
# [epoch: 1] train loss: 1.032, val loss: 0.505
# Finished window, trained for 45 epochs, loss: 0.106
# Training 2 time
# [epoch: 1] train loss: 0.633, val loss: 0.752
# Finished window, trained for 50 epochs, loss: 0.099
# Training 3 time
# [epoch: 1] train loss: 0.675, val loss: 1.016
# Finished window, trained for 63 epochs, loss: 0.055
# Training 4 time
# [epoch: 1] train loss: 0.535, val loss: 0.544
# Finished window, trained for 61 epochs, loss: 0.115
# Training 5 time
# [epoch: 1] train loss: 0.720, val loss: 0.769
# Finished window, trained for 54 epochs, loss: 0.214
# Training 6 time
# [epoch: 1] train loss: 0.761, val loss: 0.845
# Finished window, trained for 53 epochs, loss: 0.226
# Training 7 time
# [epoch: 1] train loss: 0.782, val loss: 0.571
# Finished window, trained for 55 epochs, loss: 0.070
# Training 8 time
# [epoch: 1] train loss: 0.562, val loss: 0.689
# Finished window, trained for 48 epochs, loss: 0.100
# Training 9 time
# [epoch: 1] train loss: 0.576, val loss: 0.579
# Finished window, trained for 51 epochs, loss: 0.113
# [0.05614375977025952, 0.10643736382001355, 0.09947244743679595, 0.05500512252169132, 0.11508691788915837, 0.2137093747180759, 0.22556358944492264, 0.0696707763576734, 0.0997602462193326, 0.11279528787286551]
# Training new net, 10 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.430, val loss: 0.417
# Finished window, trained for 63 epochs, loss: 0.070
# Training 1 time
# [epoch: 1] train loss: 0.856, val loss: 0.818
# Finished window, trained for 57 epochs, loss: 0.080
# Training 2 time
# [epoch: 1] train loss: 0.926, val loss: 0.702
# Finished window, trained for 29 epochs, loss: 0.237
# Training 3 time
# [epoch: 1] train loss: 0.608, val loss: 0.654
# Finished window, trained for 67 epochs, loss: 0.110
# Training 4 time
# [epoch: 1] train loss: 1.138, val loss: 0.931
# Finished window, trained for 57 epochs, loss: 0.103
# Training 5 time
# [epoch: 1] train loss: 0.852, val loss: 1.025
# Finished window, trained for 57 epochs, loss: 0.157
# Training 6 time
# [epoch: 1] train loss: 0.969, val loss: 0.898
# Finished window, trained for 45 epochs, loss: 0.186
# Training 7 time
# [epoch: 1] train loss: 0.861, val loss: 0.476
# Finished window, trained for 45 epochs, loss: 0.117
# Training 8 time
# [epoch: 1] train loss: 1.120, val loss: 0.815
# Finished window, trained for 79 epochs, loss: 0.072
# Training 9 time
# [epoch: 1] train loss: 0.340, val loss: 0.339
# Finished window, trained for 79 epochs, loss: 0.075
# [0.06957497225056274, 0.0800991456849528, 0.23706498992784572, 0.11012312417425325, 0.1032426063916372, 0.15730555747514682, 0.18597786716030293, 0.11730384709696999, 0.072002141897489, 0.07518117520912532]
# Training new net, 11 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.620, val loss: 0.989
# Finished window, trained for 60 epochs, loss: 0.082
# Training 1 time
# [epoch: 1] train loss: 0.957, val loss: 0.706
# Finished window, trained for 48 epochs, loss: 0.119
# Training 2 time
# [epoch: 1] train loss: 0.667, val loss: 0.816
# Finished window, trained for 59 epochs, loss: 0.098
# Training 3 time
# [epoch: 1] train loss: 1.000, val loss: 0.541
# Finished window, trained for 52 epochs, loss: 0.112
# Training 4 time
# [epoch: 1] train loss: 0.624, val loss: 0.838
# Finished window, trained for 39 epochs, loss: 0.120
# Training 5 time
# [epoch: 1] train loss: 0.771, val loss: 0.601
# Finished window, trained for 57 epochs, loss: 0.083
# Training 6 time
# [epoch: 1] train loss: 0.642, val loss: 0.473
# Finished window, trained for 35 epochs, loss: 0.122
# Training 7 time
# [epoch: 1] train loss: 0.573, val loss: 0.395
# Finished window, trained for 41 epochs, loss: 0.067
# Training 8 time
# [epoch: 1] train loss: 0.694, val loss: 0.554
# Finished window, trained for 19 epochs, loss: 0.197
# Training 9 time
# [epoch: 1] train loss: 0.548, val loss: 0.329
# Finished window, trained for 39 epochs, loss: 0.081
# [0.08185862028724787, 0.11852176171435298, 0.09778933681949388, 0.11195818605631881, 0.11982817437948302, 0.08254897604860803, 0.12206669782434461, 0.06698906112932508, 0.19689844924495462, 0.08138017269837505]
# Training new net, 12 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.760, val loss: 1.252
# Finished window, trained for 68 epochs, loss: 0.284
# Training 1 time
# [epoch: 1] train loss: 0.669, val loss: 1.255
# Finished window, trained for 68 epochs, loss: 0.109
# Training 2 time
# [epoch: 1] train loss: 1.187, val loss: 0.845
# Finished window, trained for 26 epochs, loss: 0.255
# Training 3 time
# [epoch: 1] train loss: 0.910, val loss: 0.987
# Finished window, trained for 27 epochs, loss: 0.180
# Training 4 time
# [epoch: 1] train loss: 1.063, val loss: 0.599
# Finished window, trained for 24 epochs, loss: 0.112
# Training 5 time
# [epoch: 1] train loss: 0.735, val loss: 0.954
# Finished window, trained for 67 epochs, loss: 0.094
# Training 6 time
# [epoch: 1] train loss: 0.583, val loss: 0.413
# Finished window, trained for 45 epochs, loss: 0.185
# Training 7 time
# [epoch: 1] train loss: 0.557, val loss: 0.384
# Finished window, trained for 21 epochs, loss: 0.185
# Training 8 time
# [epoch: 1] train loss: 0.791, val loss: 0.394
# Finished window, trained for 31 epochs, loss: 0.108
# Training 9 time
# [epoch: 1] train loss: 0.696, val loss: 1.006
# Finished window, trained for 47 epochs, loss: 0.072
# [0.2836412725869712, 0.10902945460151316, 0.2547247358380963, 0.17967235298608153, 0.11223324192254165, 0.09402580124111481, 0.18473505258067127, 0.1849416734294637, 0.10829063181162757, 0.07165711956536945]
# Training new net, 13 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.648, val loss: 0.757
# Finished window, trained for 56 epochs, loss: 0.149
# Training 1 time
# [epoch: 1] train loss: 0.513, val loss: 1.072
# Finished window, trained for 39 epochs, loss: 0.208
# Training 2 time
# [epoch: 1] train loss: 0.841, val loss: 0.890
# Finished window, trained for 50 epochs, loss: 0.095
# Training 3 time
# [epoch: 1] train loss: 1.182, val loss: 0.847
# Finished window, trained for 95 epochs, loss: 0.061
# Training 4 time
# [epoch: 1] train loss: 0.703, val loss: 0.672
# Finished window, trained for 63 epochs, loss: 0.095
# Training 5 time
# [epoch: 1] train loss: 0.921, val loss: 0.867
# Finished window, trained for 41 epochs, loss: 0.199
# Training 6 time
# [epoch: 1] train loss: 0.556, val loss: 0.445
# Finished window, trained for 55 epochs, loss: 0.075
# Training 7 time
# [epoch: 1] train loss: 0.689, val loss: 0.593
# Finished window, trained for 59 epochs, loss: 0.114
# Training 8 time
# [epoch: 1] train loss: 0.510, val loss: 0.356
# Finished window, trained for 34 epochs, loss: 0.151
# Training 9 time
# [epoch: 1] train loss: 0.647, val loss: 1.222
# Finished window, trained for 50 epochs, loss: 0.155
# [0.14899490610650723, 0.2082448497122409, 0.09547969574569816, 0.06085483702664337, 0.0952962151080297, 0.19866057548993812, 0.07542702199562508, 0.11399351234865084, 0.15110874020622353, 0.155441561747598]
# Training new net, 14 lags 6 hidden
# Training 0 time
# [epoch: 1] train loss: 0.976, val loss: 0.777
# Finished window, trained for 37 epochs, loss: 0.220
# Training 1 time
# [epoch: 1] train loss: 0.909, val loss: 0.804
# Finished window, trained for 59 epochs, loss: 0.136
# Training 2 time
# [epoch: 1] train loss: 0.934, val loss: 1.280
# Finished window, trained for 28 epochs, loss: 0.194
# Training 3 time
# [epoch: 1] train loss: 0.629, val loss: 0.722
# Finished window, trained for 56 epochs, loss: 0.151
# Training 4 time
# [epoch: 1] train loss: 0.822, val loss: 0.768
# Finished window, trained for 55 epochs, loss: 0.098
# Training 5 time
# [epoch: 1] train loss: 0.504, val loss: 0.562
# Finished window, trained for 34 epochs, loss: 0.121
# Training 6 time
# [epoch: 1] train loss: 0.927, val loss: 0.960
# Finished window, trained for 49 epochs, loss: 0.329
# Training 7 time
# [epoch: 1] train loss: 0.665, val loss: 0.927
# Finished window, trained for 43 epochs, loss: 0.344
# Training 8 time
# [epoch: 1] train loss: 0.711, val loss: 0.857
# Finished window, trained for 41 epochs, loss: 0.359
# Training 9 time
# [epoch: 1] train loss: 0.677, val loss: 0.726
# Finished window, trained for 44 epochs, loss: 0.334
# [0.2201109474101994, 0.1362752799739075, 0.19425270177729828, 0.15115548518267183, 0.09755219609828154, 0.12110671686446843, 0.32895622572304645, 0.34433524721443615, 0.35854542596886557, 0.3338692745376451]

# %%
lowest = 100000000

for k, v in losses.items():
    best_loss = v[np.argmin(v)]
    if best_loss < lowest:
        lowest = best_loss
        lowest_key = k
        
print(lowest)
print(lowest_key)
# Out:
# 0.03473095898208318
# 3-6

# %%
best_loss = []
avg_loss = []

for k, v in losses.items():
    best_net_index = np.argmin(v)
    best_loss.append(v[best_net_index])
    avg_loss.append(get_average(v))

# %%
from matplotlib import style

style.use('seaborn-poster') #sets the size of the charts
style.use('ggplot')

plt.figure(figsize=(15,10))

plt.plot([i for i in range(1, len(best_loss) + 1)], best_loss)
plt.plot([i for i in range(1, len(best_loss) + 1)], avg_loss)

plt.legend(("Lowest loss", "Average loss"), facecolor="white")
plt.xlabel("Lags", fontsize=20)
plt.ylabel("Final Validation Loss", fontsize=20)
plt.savefig('../Figs/lags_deep.png', bbox_inches='tight')

# %% [markdown]
# # Forecasts

# %%
from utils import count_parameters

# %%
lags = 3

testdata = CoreDataset(full, lags=lags, series=["CPIAUCSL", "A191RO1Q156NBEA", "UNRATE"])

testset = Subset(testdata, [i for i in range(test_start, length - lags)])

testloader = DataLoader(testset, batch_size=1, shuffle=False,
                        sampler=SequentialSampler(testset))

# %%
criterion = nn.MSELoss()

net = FeedforwardSixHidden(lags * 3, hidden_size=6)
net.load_state_dict(torch.load("Core Deep/lag3hidden6_4.pt"))

# %%
evaluate_on_test(testloader, net, criterion)
# Out:
# 0.014192036718624167

# %% [markdown]
# # Multi-step

# %%
from utils import CoreDatasetMulti

# %%
steps = 3

multitestdata = CoreDatasetMulti(full, lags=lags, series=["CPIAUCSL", "A191RO1Q156NBEA", "UNRATE"], steps=steps)

multitestset = Subset(multitestdata, [i for i in range(test_start, length - lags - steps)])

multitestloader = DataLoader(multitestset, batch_size=1, shuffle=False,
                        sampler=SequentialSampler(multitestset))

# %%
net.eval()
y_pred = []
y_act = []
running_test_loss = []

for i, data in enumerate(multitestloader):
    y, X = data
    y, X = y.float(), X.float()

    with torch.no_grad():
        forecast_1 = net(X)
        # furthest lag is last 
        forecast_2 = net(torch.cat([forecast_1, X.squeeze()[:6].unsqueeze(0)], dim=1))
        forecast_3 = net(torch.cat([forecast_2, forecast_1, X.squeeze()[:3].unsqueeze(0)], dim=1))
        
        loss = criterion(y, forecast_3)
        running_test_loss.append(loss.item())
        
        y_pred.append(forecast_3.squeeze().numpy()[0])
        y_act.append(y.squeeze().numpy()[0])

plt.plot(y_act)
plt.plot(y_pred)
plt.legend(("Test", "Forecast"), facecolor="white")
        
get_average(running_test_loss)
# Out:
# 0.14872205832713767

# %%
len(multitestloader)
# Out:
# 79
