# %%
# to import from parent directory
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, SequentialSampler, Subset
from utils import get_lags, get_average, TrainHelper, Window, CoreDataset, evaluate_on_test, init_weights, save_obj, load_obj

# %%
full = pd.read_csv('../normalised_growth.csv', index_col=0, header=[0], parse_dates=True)

# %%
class FeedforwardOneHidden(nn.Module):
    
    def __init__(self, input_size, hidden_size):
        super(FeedforwardOneHidden, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, 3)
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)  # no activation at output layer
        return x

# %%
trainer = TrainHelper(percent = 0.99, manual = 5000, print_every=1000)

PATH = "./Core One Layer/"

def train_times(times, trainer, net, criterion, optimizer, window):
    
    losses = []

    # train ten times, find best loss
    for i in range(times):
        net.apply(init_weights)
        print("Training %d time" % i)
        loss = trainer.train_window(net, criterion, optimizer, window)
        torch.save(net.state_dict(), PATH + "lag" + str(net.input_size//3) + "hidden" + str(net.hidden_size) + "_" + str(i) + ".pt")
        losses.append(loss)
        
    return losses

# %%
length = len(full.loc["1948-01-01":])
val_start = round(length * 0.8)
test_start = round(length * 0.9)

# %%
losses = load_obj("FF_Core_One_Layer_Losses")

# %%
hiddens = [8, 16, 24]

for lags in range(1, 15):
    coredata = CoreDataset(full, lags=lags, series=["CPIAUCSL", "A191RO1Q156NBEA", "UNRATE"])

    # subtract by lags to ensure same training sets
    trainset = Subset(coredata, [i for i in range(val_start - 1 - lags)])
    valset = Subset(coredata, [i for i in range(val_start - lags, test_start - 1 - lags)])

    trainloader = DataLoader(trainset, batch_size=1, shuffle=False, sampler=SequentialSampler(trainset))
    validationloader = DataLoader(valset, batch_size=1, shuffle=False, sampler=SequentialSampler(valset))

    window = Window(trainloader, validationloader)
    
    for hidden_size in hiddens:
        print("Training new net, %d lags %d hidden" % (lags, hidden_size))

        net = FeedforwardOneHidden(lags * 3, hidden_size=hidden_size)
        criterion = nn.MSELoss()
        optimizer = optim.SGD(net.parameters(), lr=0.001)
        loss = train_times(10, trainer, net, criterion, optimizer, window)
        print(loss)
        losses[str(lags) + "-" + str(hidden_size)] = loss
# Out:
# Training new net, 7 lags 8 hidden
# Training 0 time
# /Users/fredchen/JupyterProjects/macro/utils.py:351: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   torch.nn.init.xavier_uniform(m.weight)
# [epoch: 1] train loss: 0.902, val loss: 1.065
# Finished window, trained for 71 epochs, loss: 0.143
# Training 1 time
# [epoch: 1] train loss: 0.952, val loss: 0.698
# Finished window, trained for 76 epochs, loss: 0.118
# Training 2 time
# [epoch: 1] train loss: 0.678, val loss: 0.497
# Finished window, trained for 44 epochs, loss: 0.097
# Training 3 time
# [epoch: 1] train loss: 0.909, val loss: 0.420
# Finished window, trained for 48 epochs, loss: 0.076
# Training 4 time
# [epoch: 1] train loss: 0.540, val loss: 0.350
# Finished window, trained for 98 epochs, loss: 0.060
# Training 5 time
# [epoch: 1] train loss: 1.068, val loss: 0.301
# Finished window, trained for 85 epochs, loss: 0.043
# Training 6 time
# [epoch: 1] train loss: 0.990, val loss: 0.396
# Finished window, trained for 55 epochs, loss: 0.079
# Training 7 time
# [epoch: 1] train loss: 0.629, val loss: 0.373
# Finished window, trained for 45 epochs, loss: 0.117
# Training 8 time
# [epoch: 1] train loss: 0.738, val loss: 0.451
# Finished window, trained for 52 epochs, loss: 0.089
# Training 9 time
# [epoch: 1] train loss: 0.317, val loss: 0.267
# Finished window, trained for 44 epochs, loss: 0.101
# [0.14334652297993136, 0.11779917790645772, 0.09659441211569013, 0.07592820418752072, 0.05986414212980604, 0.0427382225497151, 0.07860239504005613, 0.11724374568359196, 0.08941937231495246, 0.10099789507803508]
# Training new net, 7 lags 16 hidden
# Training 0 time
# [epoch: 1] train loss: 0.724, val loss: 0.652
# Finished window, trained for 47 epochs, loss: 0.066
# Training 1 time
# [epoch: 1] train loss: 0.611, val loss: 0.466
# Finished window, trained for 41 epochs, loss: 0.085
# Training 2 time
# [epoch: 1] train loss: 0.701, val loss: 0.508
# Finished window, trained for 56 epochs, loss: 0.103
# Training 3 time
# [epoch: 1] train loss: 0.555, val loss: 0.492
# Finished window, trained for 46 epochs, loss: 0.124
# Training 4 time
# [epoch: 1] train loss: 0.688, val loss: 1.102
# Finished window, trained for 67 epochs, loss: 0.112
# Training 5 time
# [epoch: 1] train loss: 0.501, val loss: 0.433
# Finished window, trained for 39 epochs, loss: 0.152
# Training 6 time
# [epoch: 1] train loss: 0.441, val loss: 0.371
# Finished window, trained for 38 epochs, loss: 0.135
# Training 7 time
# [epoch: 1] train loss: 0.838, val loss: 0.799
# Finished window, trained for 51 epochs, loss: 0.083
# Training 8 time
# [epoch: 1] train loss: 0.497, val loss: 0.445
# Finished window, trained for 32 epochs, loss: 0.151
# Training 9 time
# [epoch: 1] train loss: 1.058, val loss: 1.113
# Finished window, trained for 57 epochs, loss: 0.103
# [0.06649667217131412, 0.08483402988178353, 0.10319419337651126, 0.12369898576677467, 0.11223540600553593, 0.15156879393730824, 0.13527345156717097, 0.08337952615784518, 0.15111426075089576, 0.10343706650036279]
# Training new net, 7 lags 24 hidden
# Training 0 time
# [epoch: 1] train loss: 0.620, val loss: 0.428
# Finished window, trained for 59 epochs, loss: 0.105
# Training 1 time
# [epoch: 1] train loss: 0.529, val loss: 0.432
# Finished window, trained for 54 epochs, loss: 0.122
# Training 2 time
# [epoch: 1] train loss: 0.562, val loss: 0.342
# Finished window, trained for 56 epochs, loss: 0.072
# Training 3 time
# [epoch: 1] train loss: 0.741, val loss: 0.439
# Finished window, trained for 37 epochs, loss: 0.083
# Training 4 time
# [epoch: 1] train loss: 0.602, val loss: 0.628
# Finished window, trained for 46 epochs, loss: 0.083
# Training 5 time
# [epoch: 1] train loss: 0.615, val loss: 0.173
# Finished window, trained for 45 epochs, loss: 0.065
# Training 6 time
# [epoch: 1] train loss: 0.641, val loss: 0.356
# Finished window, trained for 28 epochs, loss: 0.089
# Training 7 time
# [epoch: 1] train loss: 0.334, val loss: 0.227
# Finished window, trained for 28 epochs, loss: 0.109
# Training 8 time
# [epoch: 1] train loss: 0.522, val loss: 0.268
# Finished window, trained for 34 epochs, loss: 0.085
# Training 9 time
# [epoch: 1] train loss: 0.783, val loss: 0.542
# Finished window, trained for 47 epochs, loss: 0.088
# [0.10464222404932348, 0.12240887781977196, 0.07233925697259037, 0.08255565734260588, 0.08308955477231054, 0.06470331680486162, 0.08861084106679566, 0.10860496988895522, 0.08493576478840802, 0.08817267664311586]
# Training new net, 8 lags 8 hidden
# Training 0 time
# [epoch: 1] train loss: 0.764, val loss: 1.021
# Finished window, trained for 99 epochs, loss: 0.075
# Training 1 time
# [epoch: 1] train loss: 0.998, val loss: 0.610
# Finished window, trained for 31 epochs, loss: 0.102
# Training 2 time
# [epoch: 1] train loss: 0.820, val loss: 0.775
# Finished window, trained for 53 epochs, loss: 0.103
# Training 3 time
# [epoch: 1] train loss: 0.914, val loss: 0.785
# Finished window, trained for 32 epochs, loss: 0.151
# Training 4 time
# [epoch: 1] train loss: 0.727, val loss: 0.777
# Finished window, trained for 56 epochs, loss: 0.119
# Training 5 time
# [epoch: 1] train loss: 0.879, val loss: 0.506
# Finished window, trained for 37 epochs, loss: 0.114
# Training 6 time
# [epoch: 1] train loss: 0.759, val loss: 0.612
# Finished window, trained for 64 epochs, loss: 0.113
# Training 7 time
# [epoch: 1] train loss: 0.706, val loss: 0.373
# Finished window, trained for 31 epochs, loss: 0.082
# Training 8 time
# [epoch: 1] train loss: 0.734, val loss: 0.502
# Finished window, trained for 66 epochs, loss: 0.071
# Training 9 time
# [epoch: 1] train loss: 0.950, val loss: 0.323
# Finished window, trained for 32 epochs, loss: 0.098
# [0.07493283647060046, 0.10208849681303929, 0.103067176229567, 0.15052784674768976, 0.11870634946538428, 0.11392753037792976, 0.11257577881538859, 0.08162762937638178, 0.07056429959313176, 0.09797411881976159]
# Training new net, 8 lags 16 hidden
# Training 0 time
# [epoch: 1] train loss: 0.676, val loss: 0.656
# Finished window, trained for 49 epochs, loss: 0.099
# Training 1 time
# [epoch: 1] train loss: 0.708, val loss: 0.872
# Finished window, trained for 53 epochs, loss: 0.120
# Training 2 time
# [epoch: 1] train loss: 0.601, val loss: 0.309
# Finished window, trained for 61 epochs, loss: 0.125
# Training 3 time
# [epoch: 1] train loss: 0.732, val loss: 0.537
# Finished window, trained for 46 epochs, loss: 0.099
# Training 4 time
# [epoch: 1] train loss: 0.591, val loss: 0.625
# Finished window, trained for 61 epochs, loss: 0.071
# Training 5 time
# [epoch: 1] train loss: 0.623, val loss: 0.537
# Finished window, trained for 43 epochs, loss: 0.144
# Training 6 time
# [epoch: 1] train loss: 0.675, val loss: 0.378
# Finished window, trained for 33 epochs, loss: 0.085
# Training 7 time
# [epoch: 1] train loss: 0.564, val loss: 0.438
# Finished window, trained for 50 epochs, loss: 0.098
# Training 8 time
# [epoch: 1] train loss: 0.617, val loss: 0.476
# Finished window, trained for 56 epochs, loss: 0.083
# Training 9 time
# [epoch: 1] train loss: 0.539, val loss: 0.325
# Finished window, trained for 29 epochs, loss: 0.141
# [0.09903721535343257, 0.12026112644462938, 0.12540469269348678, 0.0994766320581274, 0.07108440142325764, 0.14400404813977907, 0.08545147705521872, 0.09813099290579831, 0.08342719879503563, 0.14135472056474171]
# Training new net, 8 lags 24 hidden
# Training 0 time
# [epoch: 1] train loss: 0.577, val loss: 0.486
# Finished window, trained for 47 epochs, loss: 0.104
# Training 1 time
# [epoch: 1] train loss: 0.555, val loss: 0.236
# Finished window, trained for 32 epochs, loss: 0.076
# Training 2 time
# [epoch: 1] train loss: 0.616, val loss: 0.334
# Finished window, trained for 44 epochs, loss: 0.095
# Training 3 time
# [epoch: 1] train loss: 0.439, val loss: 0.287
# Finished window, trained for 38 epochs, loss: 0.071
# Training 4 time
# [epoch: 1] train loss: 0.377, val loss: 0.386
# Finished window, trained for 38 epochs, loss: 0.120
# Training 5 time
# [epoch: 1] train loss: 0.677, val loss: 0.271
# Finished window, trained for 28 epochs, loss: 0.101
# Training 6 time
# [epoch: 1] train loss: 0.577, val loss: 0.404
# Finished window, trained for 33 epochs, loss: 0.094
# Training 7 time
# [epoch: 1] train loss: 0.606, val loss: 0.453
# Finished window, trained for 50 epochs, loss: 0.101
# Training 8 time
# [epoch: 1] train loss: 0.566, val loss: 0.758
# Finished window, trained for 44 epochs, loss: 0.131
# Training 9 time
# [epoch: 1] train loss: 0.473, val loss: 0.651
# Finished window, trained for 56 epochs, loss: 0.109
# [0.10394479070205753, 0.07593541248021284, 0.0951415819874919, 0.07090807894208268, 0.1203459477186769, 0.10065175268791077, 0.09420983689533564, 0.10066663698052448, 0.13087357186504603, 0.10854840095328422]
# Training new net, 9 lags 8 hidden
# Training 0 time
# [epoch: 1] train loss: 0.600, val loss: 0.473
# Finished window, trained for 40 epochs, loss: 0.082
# Training 1 time
# [epoch: 1] train loss: 0.760, val loss: 0.936
# Finished window, trained for 75 epochs, loss: 0.069
# Training 2 time
# [epoch: 1] train loss: 0.873, val loss: 0.592
# Finished window, trained for 101 epochs, loss: 0.054
# Training 3 time
# [epoch: 1] train loss: 0.985, val loss: 0.545
# Finished window, trained for 43 epochs, loss: 0.078
# Training 4 time
# [epoch: 1] train loss: 0.539, val loss: 0.623
# Finished window, trained for 60 epochs, loss: 0.097
# Training 5 time
# [epoch: 1] train loss: 0.487, val loss: 0.308
# Finished window, trained for 47 epochs, loss: 0.111
# Training 6 time
# [epoch: 1] train loss: 0.735, val loss: 0.301
# Finished window, trained for 70 epochs, loss: 0.095
# Training 7 time
# [epoch: 1] train loss: 0.698, val loss: 0.852
# Finished window, trained for 59 epochs, loss: 0.140
# Training 8 time
# [epoch: 1] train loss: 0.670, val loss: 0.552
# Finished window, trained for 72 epochs, loss: 0.106
# Training 9 time
# [epoch: 1] train loss: 0.804, val loss: 0.374
# Finished window, trained for 40 epochs, loss: 0.131
# [0.08226398423578882, 0.068962637316116, 0.05383913114749114, 0.0775581455944727, 0.09705592135752679, 0.11125385091827233, 0.09494908330140306, 0.14002543572409482, 0.10615293689496703, 0.13099520208654178]
# Training new net, 9 lags 16 hidden
# Training 0 time
# [epoch: 1] train loss: 0.646, val loss: 0.515
# Finished window, trained for 42 epochs, loss: 0.086
# Training 1 time
# [epoch: 1] train loss: 0.792, val loss: 0.485
# Finished window, trained for 34 epochs, loss: 0.098
# Training 2 time
# [epoch: 1] train loss: 0.698, val loss: 0.789
# Finished window, trained for 69 epochs, loss: 0.062
# Training 3 time
# [epoch: 1] train loss: 0.816, val loss: 0.386
# Finished window, trained for 61 epochs, loss: 0.111
# Training 4 time
# [epoch: 1] train loss: 0.538, val loss: 0.742
# Finished window, trained for 54 epochs, loss: 0.085
# Training 5 time
# [epoch: 1] train loss: 0.600, val loss: 0.708
# Finished window, trained for 28 epochs, loss: 0.115
# Training 6 time
# [epoch: 1] train loss: 0.483, val loss: 0.736
# Finished window, trained for 43 epochs, loss: 0.144
# Training 7 time
# [epoch: 1] train loss: 0.938, val loss: 0.517
# Finished window, trained for 33 epochs, loss: 0.104
# Training 8 time
# [epoch: 1] train loss: 0.830, val loss: 0.715
# Finished window, trained for 52 epochs, loss: 0.084
# Training 9 time
# [epoch: 1] train loss: 0.399, val loss: 0.431
# Finished window, trained for 28 epochs, loss: 0.195
# [0.08599833723742005, 0.09795556450856156, 0.06182781976656806, 0.11120103169985883, 0.08497107709762548, 0.1152579690708651, 0.1438120995262437, 0.10409776183078064, 0.08421055508101834, 0.19497532670924844]
# Training new net, 9 lags 24 hidden
# Training 0 time
# [epoch: 1] train loss: 0.449, val loss: 0.530
# Finished window, trained for 57 epochs, loss: 0.107
# Training 1 time
# [epoch: 1] train loss: 0.512, val loss: 0.444
# Finished window, trained for 43 epochs, loss: 0.084
# Training 2 time
# [epoch: 1] train loss: 0.291, val loss: 0.407
# Finished window, trained for 60 epochs, loss: 0.079
# Training 3 time
# [epoch: 1] train loss: 0.644, val loss: 0.876
# Finished window, trained for 64 epochs, loss: 0.106
# Training 4 time
# [epoch: 1] train loss: 0.662, val loss: 0.352
# Finished window, trained for 57 epochs, loss: 0.057
# Training 5 time
# [epoch: 1] train loss: 0.492, val loss: 0.454
# Finished window, trained for 45 epochs, loss: 0.133
# Training 6 time
# [epoch: 1] train loss: 0.496, val loss: 0.519
# Finished window, trained for 50 epochs, loss: 0.073
# Training 7 time
# [epoch: 1] train loss: 0.460, val loss: 0.374
# Finished window, trained for 26 epochs, loss: 0.124
# Training 8 time
# [epoch: 1] train loss: 0.542, val loss: 0.379
# Finished window, trained for 30 epochs, loss: 0.083
# Training 9 time
# [epoch: 1] train loss: 0.597, val loss: 0.752
# Finished window, trained for 64 epochs, loss: 0.077
# [0.10724062372088049, 0.0838384975460084, 0.07876335872005097, 0.10592416557454842, 0.05748657478503518, 0.13287808075421673, 0.07322182895515261, 0.1242778583190075, 0.08338990855993995, 0.0767003932387988]
# Training new net, 10 lags 8 hidden
# Training 0 time
# [epoch: 1] train loss: 0.396, val loss: 0.495
# Finished window, trained for 33 epochs, loss: 0.131
# Training 1 time
# [epoch: 1] train loss: 0.797, val loss: 0.411
# Finished window, trained for 40 epochs, loss: 0.080
# Training 2 time
# [epoch: 1] train loss: 0.791, val loss: 0.485
# Finished window, trained for 56 epochs, loss: 0.085
# Training 3 time
# [epoch: 1] train loss: 0.744, val loss: 0.494
# Finished window, trained for 57 epochs, loss: 0.093
# Training 4 time
# [epoch: 1] train loss: 0.621, val loss: 0.456
# Finished window, trained for 50 epochs, loss: 0.154
# Training 5 time
# [epoch: 1] train loss: 0.538, val loss: 0.537
# Finished window, trained for 22 epochs, loss: 0.184
# Training 6 time
# [epoch: 1] train loss: 0.467, val loss: 0.347
# Finished window, trained for 21 epochs, loss: 0.104
# Training 7 time
# [epoch: 1] train loss: 0.811, val loss: 0.322
# Finished window, trained for 35 epochs, loss: 0.113
# Training 8 time
# [epoch: 1] train loss: 0.626, val loss: 0.712
# Finished window, trained for 46 epochs, loss: 0.198
# Training 9 time
# [epoch: 1] train loss: 0.617, val loss: 0.471
# Finished window, trained for 39 epochs, loss: 0.087
# [0.13128672756469242, 0.08020262455512935, 0.08514499414105005, 0.0931596507179076, 0.15383179138617717, 0.18417450877182717, 0.10412164077393292, 0.11305235336699031, 0.19763349677075395, 0.08696117991029156]
# Training new net, 10 lags 16 hidden
# Training 0 time
# [epoch: 1] train loss: 0.605, val loss: 0.500
# Finished window, trained for 36 epochs, loss: 0.128
# Training 1 time
# [epoch: 1] train loss: 0.694, val loss: 0.480
# Finished window, trained for 46 epochs, loss: 0.118
# Training 2 time
# [epoch: 1] train loss: 0.453, val loss: 0.603
# Finished window, trained for 55 epochs, loss: 0.078
# Training 3 time
# [epoch: 1] train loss: 0.527, val loss: 0.581
# Finished window, trained for 54 epochs, loss: 0.095
# Training 4 time
# [epoch: 1] train loss: 0.506, val loss: 0.324
# Finished window, trained for 50 epochs, loss: 0.098
# Training 5 time
# [epoch: 1] train loss: 0.423, val loss: 0.385
# Finished window, trained for 32 epochs, loss: 0.100
# Training 6 time
# [epoch: 1] train loss: 0.564, val loss: 0.400
# Finished window, trained for 38 epochs, loss: 0.148
# Training 7 time
# [epoch: 1] train loss: 0.585, val loss: 0.336
# Finished window, trained for 38 epochs, loss: 0.100
# Training 8 time
# [epoch: 1] train loss: 0.653, val loss: 0.521
# Finished window, trained for 26 epochs, loss: 0.123
# Training 9 time
# [epoch: 1] train loss: 0.590, val loss: 0.661
# Finished window, trained for 53 epochs, loss: 0.089
# [0.1279411556370392, 0.1178657263060849, 0.07842338032011564, 0.09548462474143461, 0.09754276582697297, 0.09996372863944784, 0.1477934520431411, 0.1000190366710098, 0.12298216663180296, 0.08859705512375371]
# Training new net, 10 lags 24 hidden
# Training 0 time
# [epoch: 1] train loss: 0.481, val loss: 0.787
# Finished window, trained for 72 epochs, loss: 0.131
# Training 1 time
# [epoch: 1] train loss: 0.494, val loss: 0.334
# Finished window, trained for 33 epochs, loss: 0.185
# Training 2 time
# [epoch: 1] train loss: 0.389, val loss: 0.300
# Finished window, trained for 32 epochs, loss: 0.113
# Training 3 time
# [epoch: 1] train loss: 0.588, val loss: 0.926
# Finished window, trained for 54 epochs, loss: 0.119
# Training 4 time
# [epoch: 1] train loss: 0.562, val loss: 0.675
# Finished window, trained for 48 epochs, loss: 0.137
# Training 5 time
# [epoch: 1] train loss: 0.446, val loss: 0.441
# Finished window, trained for 36 epochs, loss: 0.136
# Training 6 time
# [epoch: 1] train loss: 0.587, val loss: 0.549
# Finished window, trained for 39 epochs, loss: 0.118
# Training 7 time
# [epoch: 1] train loss: 0.521, val loss: 0.372
# Finished window, trained for 29 epochs, loss: 0.140
# Training 8 time
# [epoch: 1] train loss: 0.523, val loss: 0.210
# Finished window, trained for 34 epochs, loss: 0.107
# Training 9 time
# [epoch: 1] train loss: 0.401, val loss: 0.312
# Finished window, trained for 31 epochs, loss: 0.161
# [0.13081154753979038, 0.18468370724140717, 0.11286475168502269, 0.11925631283449155, 0.13748101689076672, 0.1363559751772532, 0.11801736711618016, 0.14045076242867202, 0.1072110296486119, 0.1611529540048008]
# Training new net, 11 lags 8 hidden
# Training 0 time
# [epoch: 1] train loss: 0.763, val loss: 0.674
# Finished window, trained for 41 epochs, loss: 0.133
# Training 1 time
# [epoch: 1] train loss: 0.740, val loss: 0.629
# Finished window, trained for 68 epochs, loss: 0.119
# Training 2 time
# [epoch: 1] train loss: 0.753, val loss: 0.603
# Finished window, trained for 98 epochs, loss: 0.070
# Training 3 time
# [epoch: 1] train loss: 1.054, val loss: 0.780
# Finished window, trained for 55 epochs, loss: 0.108
# Training 4 time
# [epoch: 1] train loss: 0.961, val loss: 0.439
# Finished window, trained for 45 epochs, loss: 0.158
# Training 5 time
# [epoch: 1] train loss: 0.982, val loss: 0.391
# Finished window, trained for 40 epochs, loss: 0.122
# Training 6 time
# [epoch: 1] train loss: 0.889, val loss: 0.764
# Finished window, trained for 52 epochs, loss: 0.162
# Training 7 time
# [epoch: 1] train loss: 0.543, val loss: 0.521
# Finished window, trained for 39 epochs, loss: 0.068
# Training 8 time
# [epoch: 1] train loss: 0.711, val loss: 0.522
# Finished window, trained for 43 epochs, loss: 0.153
# Training 9 time
# [epoch: 1] train loss: 0.925, val loss: 0.489
# Finished window, trained for 31 epochs, loss: 0.141
# [0.13331748309896746, 0.11939764195669662, 0.06994369055575911, 0.10790900022884851, 0.15808284972890227, 0.1221423792754364, 0.16184611304859428, 0.06786072672682578, 0.15252093357654908, 0.14067050640507803]
# Training new net, 11 lags 16 hidden
# Training 0 time
# [epoch: 1] train loss: 0.585, val loss: 0.257
# Finished window, trained for 40 epochs, loss: 0.093
# Training 1 time
# [epoch: 1] train loss: 0.724, val loss: 0.477
# Finished window, trained for 42 epochs, loss: 0.104
# Training 2 time
# [epoch: 1] train loss: 0.493, val loss: 0.273
# Finished window, trained for 45 epochs, loss: 0.083
# Training 3 time
# [epoch: 1] train loss: 0.658, val loss: 0.332
# Finished window, trained for 46 epochs, loss: 0.125
# Training 4 time
# [epoch: 1] train loss: 0.598, val loss: 0.490
# Finished window, trained for 51 epochs, loss: 0.138
# Training 5 time
# [epoch: 1] train loss: 0.515, val loss: 0.529
# Finished window, trained for 60 epochs, loss: 0.140
# Training 6 time
# [epoch: 1] train loss: 0.551, val loss: 0.337
# Finished window, trained for 28 epochs, loss: 0.140
# Training 7 time
# [epoch: 1] train loss: 0.727, val loss: 0.427
# Finished window, trained for 28 epochs, loss: 0.192
# Training 8 time
# [epoch: 1] train loss: 0.787, val loss: 0.521
# Finished window, trained for 29 epochs, loss: 0.082
# Training 9 time
# [epoch: 1] train loss: 0.474, val loss: 1.045
# Finished window, trained for 52 epochs, loss: 0.090
# [0.09311408559590868, 0.1037733095349954, 0.08299582175198285, 0.12472799324160033, 0.13834440777872634, 0.14036206380582836, 0.1399126263737094, 0.19214643238057547, 0.08231510334607105, 0.08977091641104827]
# Training new net, 11 lags 24 hidden
# Training 0 time
# [epoch: 1] train loss: 0.343, val loss: 0.281
# Finished window, trained for 40 epochs, loss: 0.104
# Training 1 time
# [epoch: 1] train loss: 0.538, val loss: 0.820
# Finished window, trained for 51 epochs, loss: 0.113
# Training 2 time
# [epoch: 1] train loss: 0.441, val loss: 0.489
# Finished window, trained for 34 epochs, loss: 0.119
# Training 3 time
# [epoch: 1] train loss: 0.705, val loss: 0.419
# Finished window, trained for 53 epochs, loss: 0.087
# Training 4 time
# [epoch: 1] train loss: 0.711, val loss: 0.391
# Finished window, trained for 50 epochs, loss: 0.114
# Training 5 time
# [epoch: 1] train loss: 0.562, val loss: 0.425
# Finished window, trained for 37 epochs, loss: 0.090
# Training 6 time
# [epoch: 1] train loss: 0.458, val loss: 0.504
# Finished window, trained for 38 epochs, loss: 0.213
# Training 7 time
# [epoch: 1] train loss: 0.445, val loss: 0.556
# Finished window, trained for 47 epochs, loss: 0.116
# Training 8 time
# [epoch: 1] train loss: 0.436, val loss: 0.452
# Finished window, trained for 57 epochs, loss: 0.142
# Training 9 time
# [epoch: 1] train loss: 0.693, val loss: 0.319
# Finished window, trained for 39 epochs, loss: 0.100
# [0.10353120136800605, 0.11273575231305087, 0.11926789548802737, 0.08679219943074072, 0.1135600148901051, 0.09048466154935715, 0.21333722936208635, 0.11648494876446384, 0.14186795840231592, 0.10032196005922743]
# Training new net, 12 lags 8 hidden
# Training 0 time
# [epoch: 1] train loss: 0.780, val loss: 0.889
# Finished window, trained for 44 epochs, loss: 0.092
# Training 1 time
# [epoch: 1] train loss: 0.665, val loss: 0.674
# Finished window, trained for 74 epochs, loss: 0.072
# Training 2 time
# [epoch: 1] train loss: 0.749, val loss: 0.343
# Finished window, trained for 32 epochs, loss: 0.139
# Training 3 time
# [epoch: 1] train loss: 0.910, val loss: 0.442
# Finished window, trained for 30 epochs, loss: 0.116
# Training 4 time
# [epoch: 1] train loss: 0.623, val loss: 0.442
# Finished window, trained for 71 epochs, loss: 0.133
# Training 5 time
# [epoch: 1] train loss: 0.563, val loss: 0.538
# Finished window, trained for 66 epochs, loss: 0.103
# Training 6 time
# [epoch: 1] train loss: 0.618, val loss: 0.740
# Finished window, trained for 64 epochs, loss: 0.176
# Training 7 time
# [epoch: 1] train loss: 0.759, val loss: 0.718
# Finished window, trained for 54 epochs, loss: 0.166
# Training 8 time
# [epoch: 1] train loss: 0.816, val loss: 0.573
# Finished window, trained for 56 epochs, loss: 0.079
# Training 9 time
# [epoch: 1] train loss: 0.782, val loss: 0.420
# Finished window, trained for 26 epochs, loss: 0.123
# [0.09248250038819571, 0.07216145737808854, 0.13943419116206798, 0.11649554466301411, 0.13329091804894144, 0.10296232387670042, 0.17581138428204746, 0.16572739055800234, 0.07896049263006574, 0.12291432834234928]
# Training new net, 12 lags 16 hidden
# Training 0 time
# [epoch: 1] train loss: 0.598, val loss: 0.223
# Finished window, trained for 31 epochs, loss: 0.106
# Training 1 time
# [epoch: 1] train loss: 0.496, val loss: 0.753
# Finished window, trained for 59 epochs, loss: 0.114
# Training 2 time
# [epoch: 1] train loss: 0.547, val loss: 0.677
# Finished window, trained for 43 epochs, loss: 0.203
# Training 3 time
# [epoch: 1] train loss: 0.509, val loss: 0.403
# Finished window, trained for 65 epochs, loss: 0.078
# Training 4 time
# [epoch: 1] train loss: 0.679, val loss: 0.532
# Finished window, trained for 54 epochs, loss: 0.108
# Training 5 time
# [epoch: 1] train loss: 0.653, val loss: 0.439
# Finished window, trained for 25 epochs, loss: 0.196
# Training 6 time
# [epoch: 1] train loss: 0.437, val loss: 0.653
# Finished window, trained for 42 epochs, loss: 0.142
# Training 7 time
# [epoch: 1] train loss: 0.511, val loss: 0.469
# Finished window, trained for 39 epochs, loss: 0.121
# Training 8 time
# [epoch: 1] train loss: 0.681, val loss: 1.089
# Finished window, trained for 60 epochs, loss: 0.180
# Training 9 time
# [epoch: 1] train loss: 0.532, val loss: 0.657
# Finished window, trained for 36 epochs, loss: 0.201
# [0.1055533546411122, 0.11427858489777838, 0.20252441986938755, 0.07840435713456541, 0.10789033500557565, 0.19649127648239406, 0.14203265263908998, 0.12113048844267706, 0.18046815840472633, 0.20085273505834514]
# Training new net, 12 lags 24 hidden
# Training 0 time
# [epoch: 1] train loss: 0.518, val loss: 0.519
# Finished window, trained for 40 epochs, loss: 0.133
# Training 1 time
# [epoch: 1] train loss: 0.419, val loss: 0.368
# Finished window, trained for 33 epochs, loss: 0.139
# Training 2 time
# [epoch: 1] train loss: 0.528, val loss: 0.506
# Finished window, trained for 67 epochs, loss: 0.114
# Training 3 time
# [epoch: 1] train loss: 0.331, val loss: 0.420
# Finished window, trained for 28 epochs, loss: 0.130
# Training 4 time
# [epoch: 1] train loss: 0.523, val loss: 0.742
# Finished window, trained for 46 epochs, loss: 0.169
# Training 5 time
# [epoch: 1] train loss: 0.630, val loss: 0.772
# Finished window, trained for 67 epochs, loss: 0.173
# Training 6 time
# [epoch: 1] train loss: 0.606, val loss: 0.934
# Finished window, trained for 52 epochs, loss: 0.145
# Training 7 time
# [epoch: 1] train loss: 0.454, val loss: 0.502
# Finished window, trained for 41 epochs, loss: 0.115
# Training 8 time
# [epoch: 1] train loss: 0.352, val loss: 0.531
# Finished window, trained for 43 epochs, loss: 0.167
# Training 9 time
# [epoch: 1] train loss: 0.408, val loss: 0.503
# Finished window, trained for 34 epochs, loss: 0.152
# [0.1333868426658834, 0.13880713832902483, 0.11444146251260283, 0.12994148847053522, 0.16877318856342893, 0.17277299479910116, 0.14530704739302688, 0.1148251332525237, 0.16676234857672279, 0.15158256283121221]
# Training new net, 13 lags 8 hidden
# Training 0 time
# [epoch: 1] train loss: 0.710, val loss: 0.655
# Finished window, trained for 44 epochs, loss: 0.100
# Training 1 time
# [epoch: 1] train loss: 0.441, val loss: 0.954
# Finished window, trained for 75 epochs, loss: 0.172
# Training 2 time
# [epoch: 1] train loss: 0.712, val loss: 0.455
# Finished window, trained for 60 epochs, loss: 0.074
# Training 3 time
# [epoch: 1] train loss: 0.592, val loss: 0.706
# Finished window, trained for 78 epochs, loss: 0.083
# Training 4 time
# [epoch: 1] train loss: 1.145, val loss: 0.583
# Finished window, trained for 42 epochs, loss: 0.183
# Training 5 time
# [epoch: 1] train loss: 0.910, val loss: 0.490
# Finished window, trained for 50 epochs, loss: 0.188
# Training 6 time
# [epoch: 1] train loss: 0.509, val loss: 0.384
# Finished window, trained for 34 epochs, loss: 0.180
# Training 7 time
# [epoch: 1] train loss: 0.525, val loss: 0.580
# Finished window, trained for 35 epochs, loss: 0.204
# Training 8 time
# [epoch: 1] train loss: 0.654, val loss: 0.346
# Finished window, trained for 21 epochs, loss: 0.195
# Training 9 time
# [epoch: 1] train loss: 0.424, val loss: 0.884
# Finished window, trained for 38 epochs, loss: 0.372
# [0.09966912344440489, 0.17174367620404263, 0.07417567487367813, 0.0828683009355183, 0.18297744925047144, 0.1876045565376533, 0.17961468036896, 0.20400023733279393, 0.1952720025812239, 0.3716692769619198]
# Training new net, 13 lags 16 hidden
# Training 0 time
# [epoch: 1] train loss: 0.585, val loss: 0.961
# Finished window, trained for 45 epochs, loss: 0.124
# Training 1 time
# [epoch: 1] train loss: 0.580, val loss: 0.667
# Finished window, trained for 38 epochs, loss: 0.138
# Training 2 time
# [epoch: 1] train loss: 0.598, val loss: 0.852
# Finished window, trained for 51 epochs, loss: 0.128
# Training 3 time
# [epoch: 1] train loss: 0.474, val loss: 0.455
# Finished window, trained for 47 epochs, loss: 0.107
# Training 4 time
# [epoch: 1] train loss: 0.590, val loss: 0.550
# Finished window, trained for 25 epochs, loss: 0.202
# Training 5 time
# [epoch: 1] train loss: 0.583, val loss: 0.663
# Finished window, trained for 54 epochs, loss: 0.140
# Training 6 time
# [epoch: 1] train loss: 0.384, val loss: 0.224
# Finished window, trained for 41 epochs, loss: 0.136
# Training 7 time
# [epoch: 1] train loss: 0.450, val loss: 0.470
# Finished window, trained for 63 epochs, loss: 0.113
# Training 8 time
# [epoch: 1] train loss: 0.742, val loss: 0.339
# Finished window, trained for 42 epochs, loss: 0.102
# Training 9 time
# [epoch: 1] train loss: 0.578, val loss: 0.336
# Finished window, trained for 28 epochs, loss: 0.212
# [0.12410477491543061, 0.13839688308664835, 0.12779897640975116, 0.10745373437336336, 0.2016121643230173, 0.1398824716913605, 0.1362739524552964, 0.11304619614258592, 0.10214539072910032, 0.21178783321988257]
# Training new net, 13 lags 24 hidden
# Training 0 time
# [epoch: 1] train loss: 0.462, val loss: 0.669
# Finished window, trained for 59 epochs, loss: 0.113
# Training 1 time
# [epoch: 1] train loss: 0.400, val loss: 0.449
# Finished window, trained for 67 epochs, loss: 0.101
# Training 2 time
# [epoch: 1] train loss: 0.517, val loss: 0.833
# Finished window, trained for 36 epochs, loss: 0.118
# Training 3 time
# [epoch: 1] train loss: 0.662, val loss: 0.850
# Finished window, trained for 61 epochs, loss: 0.108
# Training 4 time
# [epoch: 1] train loss: 0.491, val loss: 0.536
# Finished window, trained for 46 epochs, loss: 0.120
# Training 5 time
# [epoch: 1] train loss: 0.569, val loss: 0.381
# Finished window, trained for 34 epochs, loss: 0.128
# Training 6 time
# [epoch: 1] train loss: 0.444, val loss: 0.519
# Finished window, trained for 46 epochs, loss: 0.086
# Training 7 time
# [epoch: 1] train loss: 0.621, val loss: 0.514
# Finished window, trained for 52 epochs, loss: 0.120
# Training 8 time
# [epoch: 1] train loss: 0.520, val loss: 0.233
# Finished window, trained for 45 epochs, loss: 0.077
# Training 9 time
# [epoch: 1] train loss: 0.536, val loss: 0.545
# Finished window, trained for 27 epochs, loss: 0.150
# [0.11295702103947691, 0.10065737452181672, 0.1183678784599418, 0.10811273138057075, 0.12047465334443247, 0.12799479169100547, 0.08619770540248924, 0.12029106616448869, 0.07744966646788788, 0.1498245783844123]
# Training new net, 14 lags 8 hidden
# Training 0 time
# [epoch: 1] train loss: 0.805, val loss: 1.131
# Finished window, trained for 73 epochs, loss: 0.135
# Training 1 time
# [epoch: 1] train loss: 0.619, val loss: 1.211
# Finished window, trained for 39 epochs, loss: 0.214
# Training 2 time
# [epoch: 1] train loss: 0.968, val loss: 0.571
# Finished window, trained for 37 epochs, loss: 0.112
# Training 3 time
# [epoch: 1] train loss: 0.692, val loss: 0.957
# Finished window, trained for 57 epochs, loss: 0.134
# Training 4 time
# [epoch: 1] train loss: 0.571, val loss: 0.427
# Finished window, trained for 49 epochs, loss: 0.169
# Training 5 time
# [epoch: 1] train loss: 0.892, val loss: 0.838
# Finished window, trained for 43 epochs, loss: 0.183
# Training 6 time
# [epoch: 1] train loss: 0.967, val loss: 0.782
# Finished window, trained for 59 epochs, loss: 0.120
# Training 7 time
# [epoch: 1] train loss: 0.765, val loss: 0.687
# Finished window, trained for 58 epochs, loss: 0.108
# Training 8 time
# [epoch: 1] train loss: 0.716, val loss: 0.410
# Finished window, trained for 24 epochs, loss: 0.219
# Training 9 time
# [epoch: 1] train loss: 1.162, val loss: 0.386
# Finished window, trained for 27 epochs, loss: 0.220
# [0.13532951679423125, 0.21419631441867928, 0.1117998796401034, 0.1341269141108747, 0.16921324987904918, 0.1827843065487732, 0.11992428412103989, 0.10764590725428241, 0.21861153201801545, 0.2203157902482952]
# Training new net, 14 lags 16 hidden
# Training 0 time
# [epoch: 1] train loss: 0.650, val loss: 0.666
# Finished window, trained for 60 epochs, loss: 0.090
# Training 1 time
# [epoch: 1] train loss: 0.737, val loss: 0.642
# Finished window, trained for 21 epochs, loss: 0.278
# Training 2 time
# [epoch: 1] train loss: 0.490, val loss: 0.800
# Finished window, trained for 62 epochs, loss: 0.128
# Training 3 time
# [epoch: 1] train loss: 0.504, val loss: 0.595
# Finished window, trained for 40 epochs, loss: 0.229
# Training 4 time
# [epoch: 1] train loss: 0.542, val loss: 0.471
# Finished window, trained for 47 epochs, loss: 0.087
# Training 5 time
# [epoch: 1] train loss: 0.499, val loss: 0.442
# Finished window, trained for 45 epochs, loss: 0.123
# Training 6 time
# [epoch: 1] train loss: 0.551, val loss: 0.356
# Finished window, trained for 36 epochs, loss: 0.237
# Training 7 time
# [epoch: 1] train loss: 0.538, val loss: 0.820
# Finished window, trained for 57 epochs, loss: 0.153
# Training 8 time
# [epoch: 1] train loss: 0.666, val loss: 0.780
# Finished window, trained for 45 epochs, loss: 0.184
# Training 9 time
# [epoch: 1] train loss: 0.520, val loss: 0.702
# Finished window, trained for 52 epochs, loss: 0.172
# [0.09011381836402614, 0.27832690858072145, 0.12807435341985146, 0.22882922706616515, 0.08683550348505377, 0.12335636371452198, 0.23734604614317723, 0.15281810098345958, 0.1835142600032793, 0.17224381212692927]
# Training new net, 14 lags 24 hidden
# Training 0 time
# [epoch: 1] train loss: 0.624, val loss: 0.383
# Finished window, trained for 62 epochs, loss: 0.115
# Training 1 time
# [epoch: 1] train loss: 0.661, val loss: 0.542
# Finished window, trained for 48 epochs, loss: 0.172
# Training 2 time
# [epoch: 1] train loss: 0.744, val loss: 0.626
# Finished window, trained for 35 epochs, loss: 0.162
# Training 3 time
# [epoch: 1] train loss: 0.388, val loss: 0.372
# Finished window, trained for 47 epochs, loss: 0.137
# Training 4 time
# [epoch: 1] train loss: 0.427, val loss: 0.514
# Finished window, trained for 28 epochs, loss: 0.215
# Training 5 time
# [epoch: 1] train loss: 0.436, val loss: 0.826
# Finished window, trained for 44 epochs, loss: 0.276
# Training 6 time
# [epoch: 1] train loss: 0.470, val loss: 0.462
# Finished window, trained for 38 epochs, loss: 0.148
# Training 7 time
# [epoch: 1] train loss: 0.458, val loss: 0.773
# Finished window, trained for 49 epochs, loss: 0.158
# Training 8 time
# [epoch: 1] train loss: 0.591, val loss: 0.710
# Finished window, trained for 69 epochs, loss: 0.097
# Training 9 time
# [epoch: 1] train loss: 0.639, val loss: 0.535
# Finished window, trained for 37 epochs, loss: 0.116
# [0.11462104851094658, 0.17186568428045504, 0.16209905761489413, 0.13664844892097308, 0.2148575522169909, 0.2758572530129231, 0.1478481631847007, 0.15845960045516416, 0.09689583298133907, 0.11550103544449324]

# %%
for k, v in losses.items():
    print(k)
    best_net_index = np.argmin(v)
    print("%.4f" % v[best_net_index])
    print("(%.4f)" % get_average(v))

# %%
best_loss_8 = []
avg_loss_8 = []
best_loss_16 = []
avg_loss_16 = []
best_loss_24 = []
avg_loss_24 = []

for k, v in losses.items():
    if k[1:] == str(8) or k[2:] == str(8):
        best_net_index = np.argmin(v)
        best_loss_8.append(v[best_net_index])
        avg_loss_8.append(get_average(v))
    if k[1:] == str(16) or k[2:] == str(16):
        best_net_index = np.argmin(v)
        best_loss_16.append(v[best_net_index])
        avg_loss_16.append(get_average(v))
    if k[1:] == str(24) or k[2:] == str(24):
        best_net_index = np.argmin(v)
        best_loss_24.append(v[best_net_index])
        avg_loss_24.append(get_average(v))
    
best_loss = []
avg_loss = []

for i in range(len(best_loss_8)):
    best_loss.append((best_loss_8[i] + best_loss_16[i] + best_loss_24[i]) / 3)
    avg_loss.append((avg_loss_8[i] + avg_loss_16[i] + avg_loss_24[i]) / 3)

# %%
from matplotlib import style

style.use('seaborn-poster') #sets the size of the charts
style.use('ggplot')

plt.figure(figsize=(15,10))

plt.plot([i for i in range(1, len(best_loss) + 1)], best_loss)
plt.plot([i for i in range(1, len(best_loss) + 1)], avg_loss)

plt.legend(("Lowest loss", "Average loss"), facecolor="white")
plt.xlabel("Lags", fontsize=20)
plt.ylabel("Final Validation Loss", fontsize=20)
plt.savefig('../Figs/lags_one_hidden.png', bbox_inches='tight')

# %%
avg_loss_lag = []

for i in range(2, 15):
    avg_loss_lag.append([])

for k, v in losses.items():
    for i in range(2, 15):
        if k[0] == str(i):
            avg_loss_lag[i].append(get_average(v))

# %%
avg_loss_lag = avg_loss_lag[2:-3]

# %%
plt.figure(figsize=(15,10))

for i in range(8):
    plt.plot([8, 16, 24], avg_loss_lag[i])
# plt.plot([i for i in range(1, len(best_loss) + 1)], avg_loss)

plt.legend([str(i) for i in range(2, 15)], facecolor="white")
plt.xlabel("Lags", fontsize=20)
plt.ylabel("Final Validation Loss", fontsize=20)
# plt.savefig('../Figs/lags_one_hidden.png', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Final Validation Loss')

# %%
save_obj(losses, "FF_Core_One_Layer_Losses")

# %% [markdown]
# # Forecasts

# %%
from utils import count_parameters

# %%
# best model?
lowest = 100000000

for k, v in losses.items():
    best_index = np.argmin(v)
    best_loss = v[best_index]
    if best_loss < lowest:
        lowest = best_loss
        lowest_key = k
        lowest_index = best_index
        
print(lowest)
print(lowest_key)
print(lowest_index)

# %%
lags = 2

testdata = CoreDataset(full, lags=lags, series=["CPIAUCSL", "A191RO1Q156NBEA", "UNRATE"])

testset = Subset(testdata, [i for i in range(test_start, length - lags)])

testloader = DataLoader(testset, batch_size=1, shuffle=False,
                        sampler=SequentialSampler(testset))

# %%
criterion = nn.MSELoss()

net = FeedforwardOneHidden(lags * 3, hidden_size=8)
net.load_state_dict(torch.load("Core One Layer/lag2hidden8_9.pt"))

# %%
evaluate_on_test(testloader, net, criterion)
# Out:
# 0.009590754902946863

# %%
len(testloader)
# Out:
# 85

# %%
count_parameters(net)
# Out:
# 83

# %% [markdown]
# # Multi-step

# %%
from utils import CoreDatasetMulti

# %%
steps = 3

multitestdata = CoreDatasetMulti(full, lags=lags, series=["CPIAUCSL", "A191RO1Q156NBEA", "UNRATE"], steps=steps)

multitestset = Subset(multitestdata, [i for i in range(test_start, length - lags - steps)])

multitestloader = DataLoader(multitestset, batch_size=1, shuffle=False,
                        sampler=SequentialSampler(multitestset))

# %%
net.eval()
y_pred = []
y_act = []
running_test_loss = []

for i, data in enumerate(multitestloader):
    y, X = data
    y, X = y.float(), X.float()

    with torch.no_grad():
        forecast_1 = net(X)
        # furthest lag is last 
        forecast_2 = net(torch.cat([forecast_1, X.squeeze()[:3].unsqueeze(0)], dim=1))
        forecast_3 = net(torch.cat([forecast_2, forecast_1], dim=1))
        
        loss = criterion(y, forecast_3)
        running_test_loss.append(loss.item())
        
        y_pred.append(forecast_3.squeeze().numpy()[0])
        y_act.append(y.squeeze().numpy()[0])

plt.plot(y_act)
plt.plot(y_pred)
plt.legend(("Test", "Forecast"), facecolor="white")
        
get_average(running_test_loss)
# Out:
# 0.07087437101581599

# %%
len(multitestloader)
# Out:
# 80

# %%
with torch.no_grad():
    print(X.squeeze()[3:])
    print(net(X))
    print(torch.cat((X.squeeze()[3:].unsqueeze(0), forecast_1), dim=1))
# Out:
# tensor([-0.0185,  1.7326, -0.4894])
# tensor([[-0.2227, -0.1976,  1.6681]])
# tensor([[-0.0185,  1.7326, -0.4894, -0.2227, -0.1976,  1.6681]])
